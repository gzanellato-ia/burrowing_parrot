# %% [markdown]
# <a href="https://colab.research.google.com/github/gzanellato-ia/burrowing_parrot/blob/main/whole_colony_counting.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <img src='https://drive.google.com/uc?export=view&id=1CHoxaz7sslroSHaP8IINZtgp6yuVrKZM' width=200 align='right'>
#
# #**Automatic counting of Burrowing Parrot nests**
# ##Parrot colony in El Cóndor
# ##Río Negro Province, Argentina
#
# <img src='https://drive.google.com/uc?export=view&id=1YeDCnNV4zKYsjiz_x08wCWAOPH3NaxxV' width=200 align='right'>
#
# ##### Gabriel Zanellato - Juan Masello - Gabriel Pagnossin
#
# #### July 2022

# %% [markdown]
# ## **Algorithm that executes the counting over the whole colony**
#
# <img src='https://drive.google.com/uc?export=view&id=14Qs7erhsP5T1V8KGpsfxEZuKFMnjHRVX' width=300>

# %%
# Copyright: Gabriel Zanellato, 2022
# Based on Lempitsky (2010), Fiaschi (2012), Xie(2018), Ronneberger(2015) and Waithe(2017)

from google.colab import drive
drive.mount('/content/drive/')

BASE_FOLDER = '/content/drive/My Drive/Data_loros/'
# Out:
# Mounted at /content/drive/

# %%
from skimage import io
import matplotlib.pyplot as plt
import numpy as np
import cv2
import math

# %% [markdown]
# ### Importing the images

# %%
lista_carpetas = ['Km_1', 'Km_2', 'Km_3', 'Km_4', 'Km_5', 'Km_6', 'Km_7', 'Km_8', 'Km_9', 'Km_10', 'Km_11', 'Km_12',
                  'Km_13', 'Km_14', 'Km_15', 'Km_16', 'Km_17', 'Km_18']

# %%
import os

nombres_imagenes_des      = []
nombres_imagenes_des_marc = []

for i in lista_carpetas:
    print(i)
    nombres_imagenes_des.append(os.listdir(BASE_FOLDER + '/Conteo_colonia/por_kilometro/' + i))
    nombres_imagenes_des_marc.append(os.listdir(BASE_FOLDER + '/Conteo_colonia/por_kilometro_marcadas/' + i))
# Out:
# Km_1
# Km_2
# Km_3
# Km_4
# Km_5
# Km_6
# Km_7
# Km_8
# Km_9
# Km_10
# Km_11
# Km_12
# Km_13
# Km_14
# Km_15
# Km_16
# Km_17
# Km_18

# %%
print(nombres_imagenes_des)         # list of 18 lists, each one contains the names of the images of each kilometer of the colony
print(nombres_imagenes_des_marc)    # Colab brings them messy
# Out:
# [['IMG_4434.JPG', 'IMG_4435.JPG', 'IMG_4436.JPG', 'IMG_4438.JPG', 'IMG_4439.JPG', 'IMG_4441.JPG', 'IMG_4440.JPG', 'IMG_4442.JPG', 'IMG_4443.JPG', 'IMG_4446.JPG', 'IMG_4445.JPG', 'IMG_4447.JPG', 'IMG_4448.JPG', 'IMG_4451.JPG', 'IMG_4450.JPG', 'IMG_4453.JPG', 'IMG_4452.JPG', 'IMG_4454.JPG', 'IMG_4455.JPG', 'IMG_4456.JPG', 'IMG_4457.JPG', 'IMG_4458.JPG', 'IMG_4460.JPG', 'IMG_4461.JPG', 'IMG_4462.JPG', 'IMG_4464.JPG', 'IMG_4463.JPG', 'IMG_4466.JPG', 'IMG_4465.JPG'], ['IMG_4420.JPG', 'IMG_4418.JPG', 'IMG_4421.JPG', 'IMG_4423.JPG', 'IMG_4426.JPG', 'IMG_4424.JPG', 'IMG_4428.JPG', 'IMG_4427.JPG', 'IMG_4430.JPG', 'IMG_4431.JPG'], ['IMG_4405.JPG', 'IMG_4406.JPG', 'IMG_4408.JPG', 'IMG_4409.JPG', 'IMG_4410.JPG', 'IMG_4412.JPG', 'IMG_4413.JPG', 'IMG_4415.JPG', 'IMG_4417.JPG', 'IMG_4416.JPG'], ['IMG_4400.JPG', 'IMG_4402.JPG', 'IMG_4401.JPG', 'IMG_4404.JPG', 'IMG_4398.JPG', 'IMG_4399.JPG'], ['IMG_4380.jpg', 'IMG_4381.jpg', 'IMG_4387.JPG', 'IMG_4390.JPG', 'IMG_4389.JPG', 'IMG_4391.JPG', 'IMG_4393.JPG', 'IMG_4394.JPG', 'IMG_4395.JPG', 'IMG_4396.JPG'], ['IMG_4356.jpg', 'IMG_4357.jpg', 'IMG_4358.jpg', 'IMG_4359.jpg', 'IMG_4362.jpg', 'IMG_4360.jpg', 'IMG_4363.jpg', 'IMG_4364.jpg', 'IMG_4365.jpg', 'IMG_4366.jpg', 'IMG_4367.jpg', 'IMG_4368.jpg', 'IMG_4369.jpg', 'IMG_4370.jpg', 'IMG_4371.jpg', 'IMG_4373.jpg', 'IMG_4374.jpg', 'IMG_4375.jpg', 'IMG_4376.jpg', 'IMG_4377.jpg', 'IMG_4378.jpg', 'IMG_4379.jpg', 'IMG_4337.jpg', 'IMG_4338.jpg', 'IMG_4339.jpg', 'IMG_4340.jpg', 'IMG_4341.jpg', 'IMG_4343.jpg', 'IMG_4342.jpg', 'IMG_4344.jpg', 'IMG_4345.jpg', 'IMG_4347.jpg', 'IMG_4348.jpg', 'IMG_4349.jpg', 'IMG_4350.jpg', 'IMG_4351.jpg', 'IMG_4353.jpg', 'IMG_4352.jpg', 'IMG_4354.jpg', 'IMG_4355.jpg'], ['IMG_4317.jpg', 'IMG_4318.jpg', 'IMG_4319.jpg', 'IMG_4320.jpg', 'IMG_4322.jpg', 'IMG_4321.jpg', 'IMG_4323.jpg', 'IMG_4324.jpg', 'IMG_4325.jpg', 'IMG_4326.jpg', 'IMG_4327.jpg', 'IMG_4329.jpg', 'IMG_4330.jpg', 'IMG_4331.jpg', 'IMG_4332.jpg', 'IMG_4333.jpg', 'IMG_4334.jpg', 'IMG_4335.jpg'], ['IMG_4301.jpg', 'IMG_4302.jpg', 'IMG_4303.jpg', 'IMG_4304.jpg', 'IMG_4305.jpg', 'IMG_4306.jpg', 'IMG_4308.jpg', 'IMG_4309.jpg', 'IMG_4310.jpg', 'IMG_4311.jpg', 'IMG_4312.jpg', 'IMG_4313.jpg', 'IMG_4314.jpg', 'IMG_4315.jpg'], ['IMG_4289.jpg', 'IMG_4291.jpg', 'IMG_4292.jpg', 'IMG_4293.jpg', 'IMG_4294.jpg', 'IMG_4296.jpg', 'IMG_4295.jpg', 'IMG_4298.jpg', 'IMG_4299.jpg', 'IMG_4300.jpg'], ['IMG_4273.jpg', 'IMG_4276.jpg', 'IMG_4275.jpg', 'IMG_4277.jpg', 'IMG_4278.jpg', 'IMG_4279.jpg', 'IMG_4280.jpg', 'IMG_4281.jpg', 'IMG_4282.jpg', 'IMG_4283.jpg', 'IMG_4284.jpg', 'IMG_4285.jpg', 'IMG_4286.jpg', 'IMG_4287.jpg', 'IMG_4288.jpg'], ['IMG_0976.JPG', 'IMG_0975.JPG', 'IMG_0977.JPG', 'IMG_0987.JPG', 'IMG_0986.JPG', 'IMG_0985.JPG', 'IMG_0990.JPG', 'IMG_0991.JPG', 'IMG_0989.JPG'], ['IMG_0965.JPG', 'IMG_0966.JPG', 'IMG_0970.JPG', 'IMG_0971.JPG', 'IMG_0967.JPG', 'IMG_0969.JPG'], ['IMG_0960.JPG', 'IMG_0958.JPG', 'IMG_0961.JPG', 'IMG_0962.JPG', 'IMG_0964.JPG'], ['IMG_0948.JPG', 'IMG_0950.JPG', 'IMG_0952.JPG', 'IMG_0951.JPG', 'IMG_0953.JPG', 'IMG_0956.JPG', 'IMG_0955.JPG'], ['IMG_0947.JPG', 'IMG_0946.JPG', 'IMG_0943.JPG', 'IMG_0945.JPG'], ['IMG_0913.JPG', 'IMG_0914.JPG', 'IMG_0916.JPG', 'IMG_0915.JPG', 'IMG_0917.JPG', 'IMG_0918.JPG', 'IMG_0919.JPG', 'IMG_0920.JPG', 'IMG_0921.JPG', 'IMG_0926.JPG', 'IMG_0927.JPG', 'IMG_0923.JPG', 'IMG_0931.JPG', 'IMG_0928.JPG', 'IMG_0929.JPG', 'IMG_0930.JPG'], ['IMG_0901.JPG', 'IMG_0900.JPG', 'IMG_0899.JPG', 'IMG_0905.JPG', 'IMG_0904.JPG', 'IMG_0906.JPG', 'IMG_0907.JPG', 'IMG_0909.JPG', 'IMG_0908.JPG', 'IMG_0911.JPG', 'IMG_0912.JPG', 'IMG_0910.JPG'], ['IMG_0898.JPG']]
# [['IMG_4434.jpg', 'IMG_4435.jpg', 'IMG_4436.jpg', 'IMG_4438.jpg', 'IMG_4439.jpg', 'IMG_4441.jpg', 'IMG_4440.jpg', 'IMG_4442.jpg', 'IMG_4443.jpg', 'IMG_4445.jpg', 'IMG_4446.jpg', 'IMG_4447.jpg', 'IMG_4448.jpg', 'IMG_4450.jpg', 'IMG_4451.jpg', 'IMG_4452.jpg', 'IMG_4453.jpg', 'IMG_4454.jpg', 'IMG_4455.jpg', 'IMG_4456.jpg', 'IMG_4457.jpg', 'IMG_4458.jpg', 'IMG_4460.jpg', 'IMG_4461.jpg', 'IMG_4462.jpg', 'IMG_4463.jpg', 'IMG_4464.jpg', 'IMG_4465.jpg', 'IMG_4466.jpg'], ['IMG_4418.jpg', 'IMG_4420.jpg', 'IMG_4421.jpg', 'IMG_4423.jpg', 'IMG_4424.jpg', 'IMG_4426.jpg', 'IMG_4427.jpg', 'IMG_4428.jpg', 'IMG_4430.jpg', 'IMG_4431.jpg'], ['IMG_4405.jpg', 'IMG_4406.jpg', 'IMG_4408.jpg', 'IMG_4409.jpg', 'IMG_4410.jpg', 'IMG_4412.jpg', 'IMG_4413.jpg', 'IMG_4415.jpg', 'IMG_4416.jpg', 'IMG_4417.jpg'], ['IMG_4401.jpg', 'IMG_4402.jpg', 'IMG_4404.jpg', 'IMG_4398.jpg', 'IMG_4399.jpg', 'IMG_4400.jpg'], ['IMG_4380_b.jpg', 'IMG_4381_b.jpg', 'IMG_4387.jpg', 'IMG_4389.jpg', 'IMG_4390.jpg', 'IMG_4391.jpg', 'IMG_4393.jpg', 'IMG_4394.jpg', 'IMG_4395.jpg', 'IMG_4396.jpg'], ['IMG_4340_b.jpg', 'IMG_4342_b.jpg', 'IMG_4341_b.jpg', 'IMG_4343_b.jpg', 'IMG_4345_b.jpg', 'IMG_4344_b.jpg', 'IMG_4347_b.jpg', 'IMG_4348_b.jpg', 'IMG_4350_b.jpg', 'IMG_4349_b.jpg', 'IMG_4351_b.jpg', 'IMG_4352_b.jpg', 'IMG_4353_b.jpg', 'IMG_4354_b.jpg', 'IMG_4355_b.jpg', 'IMG_4356_b.jpg', 'IMG_4357_b.jpg', 'IMG_4358_b.jpg', 'IMG_4359_b.jpg', 'IMG_4360_b.jpg', 'IMG_4362_b.jpg', 'IMG_4363_b.jpg', 'IMG_4364_b.jpg', 'IMG_4365_b.jpg', 'IMG_4366_b.jpg', 'IMG_4368_b.jpg', 'IMG_4369_b.jpg', 'IMG_4371_b.jpg', 'IMG_4370_b.jpg', 'IMG_4373_b.jpg', 'IMG_4374_b.jpg', 'IMG_4375_b.jpg', 'IMG_4376_b.jpg', 'IMG_4377_b.jpg', 'IMG_4378_b.jpg', 'IMG_4379_b.jpg', 'IMG_4337_b.jpg', 'IMG_4338_b.jpg', 'IMG_4339_b.jpg', 'IMG_4367_b.jpg'], ['IMG_4317_b.jpg', 'IMG_4318_b.jpg', 'IMG_4319_b.jpg', 'IMG_4321_b.jpg', 'IMG_4320_b.jpg', 'IMG_4322_b.jpg', 'IMG_4323_b.jpg', 'IMG_4324_b.jpg', 'IMG_4326_b.jpg', 'IMG_4325_b.jpg', 'IMG_4327_b.jpg', 'IMG_4329_b.jpg', 'IMG_4330_b.jpg', 'IMG_4331_b.jpg', 'IMG_4332_b.jpg', 'IMG_4333_b.jpg', 'IMG_4334_b.jpg', 'IMG_4335_b.jpg'], ['IMG_4301_b.jpg', 'IMG_4302_b.jpg', 'IMG_4303_b.jpg', 'IMG_4304_b.jpg', 'IMG_4305_b.jpg', 'IMG_4306_b.jpg', 'IMG_4308_b.jpg', 'IMG_4309_b.jpg', 'IMG_4310_b.jpg', 'IMG_4311_b.jpg', 'IMG_4312_b.jpg', 'IMG_4313_b.jpg', 'IMG_4315_b.jpg', 'IMG_4314_b.jpg'], ['IMG_4289_b.jpg', 'IMG_4291_b.jpg', 'IMG_4292_b.jpg', 'IMG_4293_b.jpg', 'IMG_4294_b.jpg', 'IMG_4295_b.jpg', 'IMG_4296_b.jpg', 'IMG_4298_b.jpg', 'IMG_4299_b.jpg', 'IMG_4300_b.jpg'], ['IMG_4273_b.jpg', 'IMG_4275_b.jpg', 'IMG_4276_b.jpg', 'IMG_4277_b.jpg', 'IMG_4279_b.jpg', 'IMG_4278_b.jpg', 'IMG_4280_b.jpg', 'IMG_4281_b.jpg', 'IMG_4282_b.jpg', 'IMG_4283_b.jpg', 'IMG_4284_b.jpg', 'IMG_4285_b.jpg', 'IMG_4286_b.jpg', 'IMG_4287_b.jpg', 'IMG_4288_b.jpg'], ['IMG_0975_vJFM.JPG', 'IMG_0977_vJFM.JPG', 'IMG_0976_vJFM.JPG', 'IMG_0985_vJFM.JPG', 'IMG_0990_vJFM.JPG', 'IMG_0991_vJFM.JPG', 'IMG_0986_vJFM.JPG', 'IMG_0987_vJFM.JPG', 'IMG_0989_vJFM.JPG'], ['IMG_0966_vJFM.JPG', 'IMG_0965_vJFM.JPG', 'IMG_0967_vJFM.JPG', 'IMG_0970_vJFM.JPG', 'IMG_0971_vJFM.JPG', 'IMG_0969_vJFM.JPG'], ['IMG_0958_JFM.JPG', 'IMG_0960_vJFM.JPG', 'IMG_0961_vJFM.JPG', 'IMG_0964_vJFM.JPG', 'IMG_0962_JFM.JPG'], ['IMG_0948_JFM.JPG', 'IMG_0950_JFM.JPG', 'IMG_0951_JFM.JPG', 'IMG_0952_JFM.JPG', 'IMG_0955_JFM.JPG', 'IMG_0953_vJFM.JPG', 'IMG_0956_JFM.JPG'], ['IMG_0943_G.jpg', 'IMG_0946_JFM.JPG', 'IMG_0945_G.jpg', 'IMG_0947_JFM.JPG'], ['IMG_0913_G.jpg', 'IMG_0914_G.jpg', 'IMG_0915_G.jpg', 'IMG_0916_G.jpg', 'IMG_0917_G.jpg', 'IMG_0918_G.jpg', 'IMG_0920_G.jpg', 'IMG_0919_G.jpg', 'IMG_0923_G.jpg', 'IMG_0921_G.jpg', 'IMG_0926_G.jpg', 'IMG_0927_G.jpg', 'IMG_0928_G.jpg', 'IMG_0929_G.jpg', 'IMG_0930_G.jpg', 'IMG_0931_G.jpg'], ['IMG_0899_b.jpg', 'IMG_0904_b.jpg', 'IMG_0900_b.jpg', 'IMG_0901_b.jpg', 'IMG_0905_b.jpg', 'IMG_0906_b.jpg', 'IMG_0907_b.jpg', 'IMG_0908_b.jpg', 'IMG_0909_b.jpg', 'IMG_0910_G.jpg', 'IMG_0912_G.jpg', 'IMG_0911_G.jpg'], ['IMG_0898_b.jpg']]

# %%
# Sort the lists

nombres_imagenes      = nombres_imagenes_des
nombres_imagenes_marc = nombres_imagenes_des_marc

for i in range(18):
  nombres_imagenes[i]      = sorted(nombres_imagenes_des[i])
  nombres_imagenes_marc[i] = sorted(nombres_imagenes_des_marc[i])


print(nombres_imagenes)
print('\n', nombres_imagenes_marc)
# Out:
# [['IMG_4434.JPG', 'IMG_4435.JPG', 'IMG_4436.JPG', 'IMG_4438.JPG', 'IMG_4439.JPG', 'IMG_4440.JPG', 'IMG_4441.JPG', 'IMG_4442.JPG', 'IMG_4443.JPG', 'IMG_4445.JPG', 'IMG_4446.JPG', 'IMG_4447.JPG', 'IMG_4448.JPG', 'IMG_4450.JPG', 'IMG_4451.JPG', 'IMG_4452.JPG', 'IMG_4453.JPG', 'IMG_4454.JPG', 'IMG_4455.JPG', 'IMG_4456.JPG', 'IMG_4457.JPG', 'IMG_4458.JPG', 'IMG_4460.JPG', 'IMG_4461.JPG', 'IMG_4462.JPG', 'IMG_4463.JPG', 'IMG_4464.JPG', 'IMG_4465.JPG', 'IMG_4466.JPG'], ['IMG_4418.JPG', 'IMG_4420.JPG', 'IMG_4421.JPG', 'IMG_4423.JPG', 'IMG_4424.JPG', 'IMG_4426.JPG', 'IMG_4427.JPG', 'IMG_4428.JPG', 'IMG_4430.JPG', 'IMG_4431.JPG'], ['IMG_4405.JPG', 'IMG_4406.JPG', 'IMG_4408.JPG', 'IMG_4409.JPG', 'IMG_4410.JPG', 'IMG_4412.JPG', 'IMG_4413.JPG', 'IMG_4415.JPG', 'IMG_4416.JPG', 'IMG_4417.JPG'], ['IMG_4398.JPG', 'IMG_4399.JPG', 'IMG_4400.JPG', 'IMG_4401.JPG', 'IMG_4402.JPG', 'IMG_4404.JPG'], ['IMG_4380.jpg', 'IMG_4381.jpg', 'IMG_4387.JPG', 'IMG_4389.JPG', 'IMG_4390.JPG', 'IMG_4391.JPG', 'IMG_4393.JPG', 'IMG_4394.JPG', 'IMG_4395.JPG', 'IMG_4396.JPG'], ['IMG_4337.jpg', 'IMG_4338.jpg', 'IMG_4339.jpg', 'IMG_4340.jpg', 'IMG_4341.jpg', 'IMG_4342.jpg', 'IMG_4343.jpg', 'IMG_4344.jpg', 'IMG_4345.jpg', 'IMG_4347.jpg', 'IMG_4348.jpg', 'IMG_4349.jpg', 'IMG_4350.jpg', 'IMG_4351.jpg', 'IMG_4352.jpg', 'IMG_4353.jpg', 'IMG_4354.jpg', 'IMG_4355.jpg', 'IMG_4356.jpg', 'IMG_4357.jpg', 'IMG_4358.jpg', 'IMG_4359.jpg', 'IMG_4360.jpg', 'IMG_4362.jpg', 'IMG_4363.jpg', 'IMG_4364.jpg', 'IMG_4365.jpg', 'IMG_4366.jpg', 'IMG_4367.jpg', 'IMG_4368.jpg', 'IMG_4369.jpg', 'IMG_4370.jpg', 'IMG_4371.jpg', 'IMG_4373.jpg', 'IMG_4374.jpg', 'IMG_4375.jpg', 'IMG_4376.jpg', 'IMG_4377.jpg', 'IMG_4378.jpg', 'IMG_4379.jpg'], ['IMG_4317.jpg', 'IMG_4318.jpg', 'IMG_4319.jpg', 'IMG_4320.jpg', 'IMG_4321.jpg', 'IMG_4322.jpg', 'IMG_4323.jpg', 'IMG_4324.jpg', 'IMG_4325.jpg', 'IMG_4326.jpg', 'IMG_4327.jpg', 'IMG_4329.jpg', 'IMG_4330.jpg', 'IMG_4331.jpg', 'IMG_4332.jpg', 'IMG_4333.jpg', 'IMG_4334.jpg', 'IMG_4335.jpg'], ['IMG_4301.jpg', 'IMG_4302.jpg', 'IMG_4303.jpg', 'IMG_4304.jpg', 'IMG_4305.jpg', 'IMG_4306.jpg', 'IMG_4308.jpg', 'IMG_4309.jpg', 'IMG_4310.jpg', 'IMG_4311.jpg', 'IMG_4312.jpg', 'IMG_4313.jpg', 'IMG_4314.jpg', 'IMG_4315.jpg'], ['IMG_4289.jpg', 'IMG_4291.jpg', 'IMG_4292.jpg', 'IMG_4293.jpg', 'IMG_4294.jpg', 'IMG_4295.jpg', 'IMG_4296.jpg', 'IMG_4298.jpg', 'IMG_4299.jpg', 'IMG_4300.jpg'], ['IMG_4273.jpg', 'IMG_4275.jpg', 'IMG_4276.jpg', 'IMG_4277.jpg', 'IMG_4278.jpg', 'IMG_4279.jpg', 'IMG_4280.jpg', 'IMG_4281.jpg', 'IMG_4282.jpg', 'IMG_4283.jpg', 'IMG_4284.jpg', 'IMG_4285.jpg', 'IMG_4286.jpg', 'IMG_4287.jpg', 'IMG_4288.jpg'], ['IMG_0975.JPG', 'IMG_0976.JPG', 'IMG_0977.JPG', 'IMG_0985.JPG', 'IMG_0986.JPG', 'IMG_0987.JPG', 'IMG_0989.JPG', 'IMG_0990.JPG', 'IMG_0991.JPG'], ['IMG_0965.JPG', 'IMG_0966.JPG', 'IMG_0967.JPG', 'IMG_0969.JPG', 'IMG_0970.JPG', 'IMG_0971.JPG'], ['IMG_0958.JPG', 'IMG_0960.JPG', 'IMG_0961.JPG', 'IMG_0962.JPG', 'IMG_0964.JPG'], ['IMG_0948.JPG', 'IMG_0950.JPG', 'IMG_0951.JPG', 'IMG_0952.JPG', 'IMG_0953.JPG', 'IMG_0955.JPG', 'IMG_0956.JPG'], ['IMG_0943.JPG', 'IMG_0945.JPG', 'IMG_0946.JPG', 'IMG_0947.JPG'], ['IMG_0913.JPG', 'IMG_0914.JPG', 'IMG_0915.JPG', 'IMG_0916.JPG', 'IMG_0917.JPG', 'IMG_0918.JPG', 'IMG_0919.JPG', 'IMG_0920.JPG', 'IMG_0921.JPG', 'IMG_0923.JPG', 'IMG_0926.JPG', 'IMG_0927.JPG', 'IMG_0928.JPG', 'IMG_0929.JPG', 'IMG_0930.JPG', 'IMG_0931.JPG'], ['IMG_0899.JPG', 'IMG_0900.JPG', 'IMG_0901.JPG', 'IMG_0904.JPG', 'IMG_0905.JPG', 'IMG_0906.JPG', 'IMG_0907.JPG', 'IMG_0908.JPG', 'IMG_0909.JPG', 'IMG_0910.JPG', 'IMG_0911.JPG', 'IMG_0912.JPG'], ['IMG_0898.JPG']]
#
#  [['IMG_4434.jpg', 'IMG_4435.jpg', 'IMG_4436.jpg', 'IMG_4438.jpg', 'IMG_4439.jpg', 'IMG_4440.jpg', 'IMG_4441.jpg', 'IMG_4442.jpg', 'IMG_4443.jpg', 'IMG_4445.jpg', 'IMG_4446.jpg', 'IMG_4447.jpg', 'IMG_4448.jpg', 'IMG_4450.jpg', 'IMG_4451.jpg', 'IMG_4452.jpg', 'IMG_4453.jpg', 'IMG_4454.jpg', 'IMG_4455.jpg', 'IMG_4456.jpg', 'IMG_4457.jpg', 'IMG_4458.jpg', 'IMG_4460.jpg', 'IMG_4461.jpg', 'IMG_4462.jpg', 'IMG_4463.jpg', 'IMG_4464.jpg', 'IMG_4465.jpg', 'IMG_4466.jpg'], ['IMG_4418.jpg', 'IMG_4420.jpg', 'IMG_4421.jpg', 'IMG_4423.jpg', 'IMG_4424.jpg', 'IMG_4426.jpg', 'IMG_4427.jpg', 'IMG_4428.jpg', 'IMG_4430.jpg', 'IMG_4431.jpg'], ['IMG_4405.jpg', 'IMG_4406.jpg', 'IMG_4408.jpg', 'IMG_4409.jpg', 'IMG_4410.jpg', 'IMG_4412.jpg', 'IMG_4413.jpg', 'IMG_4415.jpg', 'IMG_4416.jpg', 'IMG_4417.jpg'], ['IMG_4398.jpg', 'IMG_4399.jpg', 'IMG_4400.jpg', 'IMG_4401.jpg', 'IMG_4402.jpg', 'IMG_4404.jpg'], ['IMG_4380_b.jpg', 'IMG_4381_b.jpg', 'IMG_4387.jpg', 'IMG_4389.jpg', 'IMG_4390.jpg', 'IMG_4391.jpg', 'IMG_4393.jpg', 'IMG_4394.jpg', 'IMG_4395.jpg', 'IMG_4396.jpg'], ['IMG_4337_b.jpg', 'IMG_4338_b.jpg', 'IMG_4339_b.jpg', 'IMG_4340_b.jpg', 'IMG_4341_b.jpg', 'IMG_4342_b.jpg', 'IMG_4343_b.jpg', 'IMG_4344_b.jpg', 'IMG_4345_b.jpg', 'IMG_4347_b.jpg', 'IMG_4348_b.jpg', 'IMG_4349_b.jpg', 'IMG_4350_b.jpg', 'IMG_4351_b.jpg', 'IMG_4352_b.jpg', 'IMG_4353_b.jpg', 'IMG_4354_b.jpg', 'IMG_4355_b.jpg', 'IMG_4356_b.jpg', 'IMG_4357_b.jpg', 'IMG_4358_b.jpg', 'IMG_4359_b.jpg', 'IMG_4360_b.jpg', 'IMG_4362_b.jpg', 'IMG_4363_b.jpg', 'IMG_4364_b.jpg', 'IMG_4365_b.jpg', 'IMG_4366_b.jpg', 'IMG_4367_b.jpg', 'IMG_4368_b.jpg', 'IMG_4369_b.jpg', 'IMG_4370_b.jpg', 'IMG_4371_b.jpg', 'IMG_4373_b.jpg', 'IMG_4374_b.jpg', 'IMG_4375_b.jpg', 'IMG_4376_b.jpg', 'IMG_4377_b.jpg', 'IMG_4378_b.jpg', 'IMG_4379_b.jpg'], ['IMG_4317_b.jpg', 'IMG_4318_b.jpg', 'IMG_4319_b.jpg', 'IMG_4320_b.jpg', 'IMG_4321_b.jpg', 'IMG_4322_b.jpg', 'IMG_4323_b.jpg', 'IMG_4324_b.jpg', 'IMG_4325_b.jpg', 'IMG_4326_b.jpg', 'IMG_4327_b.jpg', 'IMG_4329_b.jpg', 'IMG_4330_b.jpg', 'IMG_4331_b.jpg', 'IMG_4332_b.jpg', 'IMG_4333_b.jpg', 'IMG_4334_b.jpg', 'IMG_4335_b.jpg'], ['IMG_4301_b.jpg', 'IMG_4302_b.jpg', 'IMG_4303_b.jpg', 'IMG_4304_b.jpg', 'IMG_4305_b.jpg', 'IMG_4306_b.jpg', 'IMG_4308_b.jpg', 'IMG_4309_b.jpg', 'IMG_4310_b.jpg', 'IMG_4311_b.jpg', 'IMG_4312_b.jpg', 'IMG_4313_b.jpg', 'IMG_4314_b.jpg', 'IMG_4315_b.jpg'], ['IMG_4289_b.jpg', 'IMG_4291_b.jpg', 'IMG_4292_b.jpg', 'IMG_4293_b.jpg', 'IMG_4294_b.jpg', 'IMG_4295_b.jpg', 'IMG_4296_b.jpg', 'IMG_4298_b.jpg', 'IMG_4299_b.jpg', 'IMG_4300_b.jpg'], ['IMG_4273_b.jpg', 'IMG_4275_b.jpg', 'IMG_4276_b.jpg', 'IMG_4277_b.jpg', 'IMG_4278_b.jpg', 'IMG_4279_b.jpg', 'IMG_4280_b.jpg', 'IMG_4281_b.jpg', 'IMG_4282_b.jpg', 'IMG_4283_b.jpg', 'IMG_4284_b.jpg', 'IMG_4285_b.jpg', 'IMG_4286_b.jpg', 'IMG_4287_b.jpg', 'IMG_4288_b.jpg'], ['IMG_0975_vJFM.JPG', 'IMG_0976_vJFM.JPG', 'IMG_0977_vJFM.JPG', 'IMG_0985_vJFM.JPG', 'IMG_0986_vJFM.JPG', 'IMG_0987_vJFM.JPG', 'IMG_0989_vJFM.JPG', 'IMG_0990_vJFM.JPG', 'IMG_0991_vJFM.JPG'], ['IMG_0965_vJFM.JPG', 'IMG_0966_vJFM.JPG', 'IMG_0967_vJFM.JPG', 'IMG_0969_vJFM.JPG', 'IMG_0970_vJFM.JPG', 'IMG_0971_vJFM.JPG'], ['IMG_0958_JFM.JPG', 'IMG_0960_vJFM.JPG', 'IMG_0961_vJFM.JPG', 'IMG_0962_JFM.JPG', 'IMG_0964_vJFM.JPG'], ['IMG_0948_JFM.JPG', 'IMG_0950_JFM.JPG', 'IMG_0951_JFM.JPG', 'IMG_0952_JFM.JPG', 'IMG_0953_vJFM.JPG', 'IMG_0955_JFM.JPG', 'IMG_0956_JFM.JPG'], ['IMG_0943_G.jpg', 'IMG_0945_G.jpg', 'IMG_0946_JFM.JPG', 'IMG_0947_JFM.JPG'], ['IMG_0913_G.jpg', 'IMG_0914_G.jpg', 'IMG_0915_G.jpg', 'IMG_0916_G.jpg', 'IMG_0917_G.jpg', 'IMG_0918_G.jpg', 'IMG_0919_G.jpg', 'IMG_0920_G.jpg', 'IMG_0921_G.jpg', 'IMG_0923_G.jpg', 'IMG_0926_G.jpg', 'IMG_0927_G.jpg', 'IMG_0928_G.jpg', 'IMG_0929_G.jpg', 'IMG_0930_G.jpg', 'IMG_0931_G.jpg'], ['IMG_0899_b.jpg', 'IMG_0900_b.jpg', 'IMG_0901_b.jpg', 'IMG_0904_b.jpg', 'IMG_0905_b.jpg', 'IMG_0906_b.jpg', 'IMG_0907_b.jpg', 'IMG_0908_b.jpg', 'IMG_0909_b.jpg', 'IMG_0910_G.jpg', 'IMG_0911_G.jpg', 'IMG_0912_G.jpg'], ['IMG_0898_b.jpg']]

# %%
# Count the number of images in each kilometer

km = 0
for i in nombres_imagenes:
    km += 1
    print('Km %i: %i images'%(km, len(i)))
# Out:
# Km 1: 29 images
# Km 2: 10 images
# Km 3: 10 images
# Km 4: 6 images
# Km 5: 10 images
# Km 6: 40 images
# Km 7: 18 images
# Km 8: 14 images
# Km 9: 10 images
# Km 10: 15 images
# Km 11: 9 images
# Km 12: 6 images
# Km 13: 5 images
# Km 14: 7 images
# Km 15: 4 images
# Km 16: 16 images
# Km 17: 12 images
# Km 18: 1 images

# %%
# Import the libraries

from keras import backend as K
import tensorflow as tf
print(tf.__version__)
from tensorflow import keras
# Out:
# 2.12.0

# %%
# Loss functions

def mae(y_true, y_pred):
    """
    Function to compute the loss of the neural network at the end of each epoch
    """
    return K.mean(abs(y_pred - y_true))

def rmse(y_true, y_pred):
    """
    Function to compute the loss of the neural network at the end of each epoch
    """
    return K.sqrt(K.mean(K.square(y_pred - y_true)))

# Metric

def r2(y_true, y_pred):
    """
    Function to define r2 values as metric of the neural network at the end of each epoch
    """
    SS_res =  K.sum(K.square( y_true-y_pred ))
    SS_tot = K.sum(K.square( y_true - K.mean(y_true) ) )
    return ( 1 - SS_res/(SS_tot + K.epsilon()) )

# %%
y_train_max = 0.04827504360859346   # from the training algorithm
factor = 255. / y_train_max
factor
# Out:
# 5282.23241117088

# %% [markdown]
# ### Define the model to use

# %%
# Define the model for the counting

modelo = 'model_ResUNet_s3_e80.h5'

# %%
BASE_FOLDER + modelo
# Out:
# '/content/drive/My Drive/Data_loros/model_ResUNet_s3_e80.h5'

# %%
cont = 0

conteo_colonia = []

for i in range(len(lista_carpetas)):    # 18 folders
    print('Sector: %s, %i images \n'%(lista_carpetas[i], len(nombres_imagenes[i])))

    conteo_kilometro = []

    km = []
    km_marc = []

    for j in range(len(nombres_imagenes[i])):   # 222 images in total

        conteo_imagen = []

        print(str(j+1) + ': ' + lista_carpetas[i] + '/' + nombres_imagenes[i][j])
        img      = np.array(io.imread(BASE_FOLDER + '/Conteo_colonia/por_kilometro/' + lista_carpetas[i] + '/' + nombres_imagenes[i][j]))
        img_marc = np.array(io.imread(BASE_FOLDER + '/Conteo_colonia/por_kilometro_marcadas/' + lista_carpetas[i] + '/' + nombres_imagenes_marc[i][j]))

        print('img.shape', img.shape)

        # converting BGR to RGB (Skimage and Open CV work with different channel order)
        # https://stackoverflow.com/questions/55128386/python-opencv-depth-of-image-unsupported-cv-64f
        img_marc_rgb = cv2.cvtColor(img_marc.astype(np.uint8), cv2.COLOR_BGR2RGB)

        # Detect the position of yellow lines
        # https://stackoverflow.com/questions/63462731/about-line-detection-by-using-opencv

        hsv = cv2.cvtColor(img_marc_rgb, cv2.COLOR_BGR2HSV)

        low_yellow = np.array([10, 94, 150])
        up_yellow = np.array([40, 255, 255])
        mask = cv2.inRange(hsv, low_yellow, up_yellow)
        edges = cv2.Canny(mask, 75, 150)

        lines = cv2.HoughLinesP(edges, 1, np.pi/180, 50, maxLineGap=250)

        # not all images have marked vertical yellow lines
        NoneType = type(None)   # https://stackoverflow.com/questions/41928835/how-to-access-the-nonetype-type
                                # type(lines) -> NoteType

        if type(lines) == NoneType:

            lim_izq = 0
            lim_der = img.shape[1]

        else:

            # We eliminate the lines with a slope less than 5 to be left only with the vertical ones
            lines_vert = []
            for line in lines:
                if abs((line[0][3]-line[0][1])/(line[0][2]-line[0][0]))>5:
                    lines_vert.append(line)

            lista_lineas = []
            for line in lines_vert:
                    lista_lineas.append(line[0][0])

            if len(lines_vert) == 0:   # in case the algorithm detects horizontal and not vertical lines (eg. IMG_0985.jpg)

                lim_izq = 0
                lim_der = img.shape[1]

            else:

              lim_izq = min(lista_lineas)
              lim_der = max(lista_lineas)

        print('\n   Horizontal position of vertical lines:')
        print('   left_limit: %d px, rigth_limit: %d px'%(lim_izq, lim_der))

        # WE PATCH!!! #######################################

        ancho = lim_der - lim_izq
        print('   net width:', ancho, 'px\n')

        nro_pasos_hor = ancho // 256
        nro_pasos_ver = img.shape[0] // 256

        # we left the first upper row (sky) and last lower row (beach) unpatched > steps_ver = 9
        # We calculate the height and width of the step
        long_parche = ancho // nro_pasos_hor

        nro_pasos_ver = 9
        lim_sup_parche = 0

        lista_parches = []

        for k in range(nro_pasos_ver):

            lim_sup_parche += 256
            lim_izq_parche = lim_izq

            for l in range(nro_pasos_hor):

                parche         = img[lim_sup_parche:lim_sup_parche+long_parche, lim_izq_parche:lim_izq_parche+long_parche]
                parche_256x256 = cv2.resize(parche, dsize=(256, 256), interpolation=cv2.INTER_CUBIC) # resize to 256x2556

                lista_parches.append(parche_256x256)
                lim_izq_parche += long_parche

        parches = np.array(lista_parches)/255.  # We convert it to a Numpy array
        print('   patches.shape', parches.shape)

        # CALL THE MODEL
        new_model = keras.models.load_model(BASE_FOLDER + modelo, custom_objects={'rmse': rmse, 'r2': r2})

        # PREDICT
        pred  = new_model.predict(parches, batch_size=4)      # dimensions delivered (patches qty., 256, 256, 1)
        pred_ = np.squeeze(pred, axis=3)

        # de-scale the density maps to correct values
        dens_pred_descaled = pred_ / factor

        # COUNT THE OBJECTS #######################################################################################

        for m in range(len(lista_parches)):

            conteo_parche = dens_pred_descaled[m].sum()
            conteo_imagen.append(conteo_parche)

        # total image count
        conteo_imagen_ = sum(conteo_imagen)
        print('   \nTotal image count, %s = %.1f'%(nombres_imagenes[i][j], conteo_imagen_))
        print('____________________________________________________\n')


        with open(BASE_FOLDER + '/Conteo_colonia/resultados_conteo_' + modelo + '.txt', 'a') as f:

            f.write(str(j+1) + ': ' + lista_carpetas[i] + '/' + nombres_imagenes[i][j])
            f.write('\n\n')
            for line_text in range(len(lista_parches)):

                f.write('Patch %d count  ='%(line_text+1) + ' %.2f' %conteo_imagen[line_text])
                f.write('\n')
            f.write('\nTotal image count, %s = %.1f \n'%(nombres_imagenes[i][j], conteo_imagen_))
            f.write('____________________________________________________\n')
            f.write('\n')


        conteo_kilometro.append(conteo_imagen_)

    conteo_kilometro_ = sum(conteo_kilometro)

    print('\nTotal count, sector %s = %.1f \n\n'%(lista_carpetas[i], conteo_kilometro_))

    with open(BASE_FOLDER + '/Conteo_colonia/resultados_conteo_' + modelo + '.txt', 'a') as f:
            f.write('\nTotal count, sector %s = %.1f \n\n'%(lista_carpetas[i], conteo_kilometro_))
            f.write('\n')

    conteo_colonia.append(conteo_kilometro_)

    cont+=1

conteo_colonia_ = sum(conteo_colonia)
print('\n############### TOTAL COLONY COUNT = %.1f NEST ENTRANCES ###############'%(conteo_colonia_))

with open(BASE_FOLDER + '/Conteo_colonia/resultados_conteo_' + modelo + '.txt', 'a') as f:
        f.write('\n############### TOTAL COLONY COUNT = %.1f NEST ENTRANCES ###############'%(conteo_colonia_))
# Out:
# Sector: Km_1, 29 images
#
# 1: Km_1/IMG_4434.JPG
# img.shape (3168, 4752, 3)
# <ipython-input-15-1fe9f8958ff0>:53: RuntimeWarning: divide by zero encountered in int_scalars
#   if abs((line[0][3]-line[0][1])/(line[0][2]-line[0][0]))>5:
#    Horizontal position of vertical lines:
#    left_limit: 291 px, rigth_limit: 4166 px
#    net width: 3875 px
#
#    patches.shape (135, 256, 256, 3)
# 34/34 [==============================] - 7s 192ms/step
#
# Total image count, IMG_4434.JPG = 200.3
# ____________________________________________________
#
# 2: Km_1/IMG_4435.JPG
# img.shape (3168, 4752, 3)
#
#    Horizontal position of vertical lines:
#    left_limit: 904 px, rigth_limit: 3929 px
#    net width: 3025 px
#
#    patches.shape (99, 256, 256, 3)
# 25/25 [==============================] - 5s 192ms/step
#
# Total image count, IMG_4435.JPG = 368.5
# ____________________________________________________
#
# 3: Km_1/IMG_4436.JPG
# img.shape (3168, 4752, 3)
#
#    Horizontal position of vertical lines:
#    left_limit: 853 px, rigth_limit: 3669 px
#    net width: 2816 px
#
#    patches.shape (99, 256, 256, 3)
# 25/25 [==============================] - 5s 192ms/step
#
# Total image count, IMG_4436.JPG = 375.2
# ____________________________________________________
#
# 4: Km_1/IMG_4438.JPG
# img.shape (3168, 4752, 3)
#
#    Horizontal position of vertical lines:
#    left_limit: 357 px, rigth_limit: 4120 px
#    net width: 3763 px
#
#    patches.shape (126, 256, 256, 3)
# 32/32 [==============================] - 7s 191ms/step
#
# Total image count, IMG_4438.JPG = 128.7
# ____________________________________________________
#
# 5: Km_1/IMG_4439.JPG
# img.shape (3168, 4752, 3)
#
#    Horizontal position of vertical lines:
#    left_limit: 553 px, rigth_limit: 3390 px
#    net width: 2837 px
#
#    patches.shape (99, 256, 256, 3)
# 25/25 [==============================] - 5s 192ms/step
#
# Total image count, IMG_4439.JPG = 138.9
# ____________________________________________________
#
# 6: Km_1/IMG_4440.JPG
# img.shape (3168, 4752, 3)
#
#    Horizontal position of vertical lines:
#    left_limit: 268 px, rigth_limit: 3712 px
#    net width: 3444 px
#
#    patches.shape (117, 256, 256, 3)
# 30/30 [==============================] - 6s 190ms/step
#
# Total image count, IMG_4440.JPG = 154.2
# ____________________________________________________
#
# 7: Km_1/IMG_4441.JPG
# img.shape (3168, 4752, 3)
#
#    Horizontal position of vertical lines:
#    left_limit: 535 px, rigth_limit: 4085 px
#    net width: 3550 px
#
#    patches.shape (117, 256, 256, 3)
# 30/30 [==============================] - 6s 191ms/step
#
# Total image count, IMG_4441.JPG = 231.8
# ____________________________________________________
#
# 8: Km_1/IMG_4442.JPG
# img.shape (3168, 4752, 3)
#
#    Horizontal position of vertical lines:
#    left_limit: 382 px, rigth_limit: 3657 px
#    net width: 3275 px
#
#    patches.shape (108, 256, 256, 3)
# 27/27 [==============================] - 6s 193ms/step
#
# Total image count, IMG_4442.JPG = 307.5
# ____________________________________________________
#
# 9: Km_1/IMG_4443.JPG
# img.shape (3168, 4752, 3)
#
#    Horizontal position of vertical lines:
#    left_limit: 394 px, rigth_limit: 3821 px
#    net width: 3427 px
#
#    patches.shape (117, 256, 256, 3)
# 30/30 [==============================] - 6s 192ms/step
#
# Total image count, IMG_4443.JPG = 158.9
# ____________________________________________________
#
# 10: Km_1/IMG_4445.JPG
# img.shape (3168, 4752, 3)
#
#    Horizontal position of vertical lines:
#    left_limit: 632 px, rigth_limit: 4398 px
#    net width: 3766 px
#
#    patches.shape (126, 256, 256, 3)
# 32/32 [==============================] - 6s 191ms/step
#
# Total image count, IMG_4445.JPG = 74.0
# ____________________________________________________
#
# 11: Km_1/IMG_4446.JPG
# img.shape (3168, 4752, 3)
#
#    Horizontal position of vertical lines:
#    left_limit: 1789 px, rigth_limit: 4500 px
#    net width: 2711 px
#
#    patches.shape (90, 256, 256, 3)
# 23/23 [==============================] - 5s 191ms/step
#
# Total image count, IMG_4446.JPG = 7.4
# ____________________________________________________
#
# 12: Km_1/IMG_4447.JPG
# img.shape (3168, 4752, 3)
#
#    Horizontal position of vertical lines:
#    left_limit: 1247 px, rigth_limit: 3629 px
#    net width: 2382 px
#
#    patches.shape (81, 256, 256, 3)
# 21/21 [==============================] - 5s 194ms/step
#
# Total image count, IMG_4447.JPG = 84.8
# ____________________________________________________
#
# 13: Km_1/IMG_4448.JPG
# img.shape (3168, 4752, 3)
#
#    Horizontal position of vertical lines:
#    left_limit: 152 px, rigth_limit: 3350 px
#    net width: 3198 px
#
#    patches.shape (108, 256, 256, 3)
# 27/27 [==============================] - 6s 194ms/step
#
# Total image count, IMG_4448.JPG = 440.9
# ____________________________________________________
#
# 14: Km_1/IMG_4450.JPG
# img.shape (3168, 4752, 3)
#
#    Horizontal position of vertical lines:
#    left_limit: 369 px, rigth_limit: 3878 px
#    net width: 3509 px
#
#    patches.shape (117, 256, 256, 3)
# 30/30 [==============================] - 6s 194ms/step
#
# Total image count, IMG_4450.JPG = 253.5
# ____________________________________________________
#
# 15: Km_1/IMG_4451.JPG
# img.shape (3168, 4752, 3)
#
#    Horizontal position of vertical lines:
#    left_limit: 377 px, rigth_limit: 2985 px
#    net width: 2608 px
#
#    patches.shape (90, 256, 256, 3)
# 23/23 [==============================] - 5s 196ms/step
#
# Total image count, IMG_4451.JPG = 151.3
# ____________________________________________________
#
# 16: Km_1/IMG_4452.JPG
# img.shape (3168, 4752, 3)
#
#    Horizontal position of vertical lines:
#    left_limit: 328 px, rigth_limit: 3953 px
#    net width: 3625 px
#
#    patches.shape (126, 256, 256, 3)
# 32/32 [==============================] - 7s 196ms/step
#
# Total image count, IMG_4452.JPG = 310.5
# ____________________________________________________
#
# 17: Km_1/IMG_4453.JPG
# img.shape (3168, 4752, 3)
#
#    Horizontal position of vertical lines:
#    left_limit: 250 px, rigth_limit: 3437 px
#    net width: 3187 px
#
#    patches.shape (108, 256, 256, 3)
# 27/27 [==============================] - 6s 195ms/step
#
# Total image count, IMG_4453.JPG = 284.4
# ____________________________________________________
#
# 18: Km_1/IMG_4454.JPG
# img.shape (3168, 4752, 3)
#
#    Horizontal position of vertical lines:
#    left_limit: 683 px, rigth_limit: 3118 px
#    net width: 2435 px
#
#    patches.shape (81, 256, 256, 3)
# 21/21 [==============================] - 4s 196ms/step
#
# Total image count, IMG_4454.JPG = 223.6
# ____________________________________________________
#
# 19: Km_1/IMG_4455.JPG
# img.shape (3168, 4752, 3)
#
#    Horizontal position of vertical lines:
#    left_limit: 304 px, rigth_limit: 3741 px
#    net width: 3437 px
#
#    patches.shape (117, 256, 256, 3)
# 30/30 [==============================] - 6s 195ms/step
#
# Total image count, IMG_4455.JPG = 367.8
# ____________________________________________________
#
# 20: Km_1/IMG_4456.JPG
# img.shape (3168, 4752, 3)
#
#    Horizontal position of vertical lines:
#    left_limit: 476 px, rigth_limit: 3735 px
#    net width: 3259 px
#
#    patches.shape (108, 256, 256, 3)
# 27/27 [==============================] - 6s 197ms/step
#
# Total image count, IMG_4456.JPG = 216.8
# ____________________________________________________
#
# 21: Km_1/IMG_4457.JPG
# img.shape (3168, 4752, 3)
# <ipython-input-15-1fe9f8958ff0>:53: RuntimeWarning: invalid value encountered in int_scalars
#   if abs((line[0][3]-line[0][1])/(line[0][2]-line[0][0]))>5:
#    Horizontal position of vertical lines:
#    left_limit: 520 px, rigth_limit: 3664 px
#    net width: 3144 px
#
#    patches.shape (108, 256, 256, 3)
# 27/27 [==============================] - 6s 197ms/step
#
# Total image count, IMG_4457.JPG = 126.0
# ____________________________________________________
#
# 22: Km_1/IMG_4458.JPG
# img.shape (3168, 4752, 3)
#
#    Horizontal position of vertical lines:
#    left_limit: 646 px, rigth_limit: 3759 px
#    net width: 3113 px
#
#    patches.shape (108, 256, 256, 3)
# 27/27 [==============================] - 6s 194ms/step
#
# Total image count, IMG_4458.JPG = 213.4
# ____________________________________________________
#
# 23: Km_1/IMG_4460.JPG
# img.shape (3168, 4752, 3)
#
#    Horizontal position of vertical lines:
#    left_limit: 789 px, rigth_limit: 3728 px
#    net width: 2939 px
#
#    patches.shape (99, 256, 256, 3)
# 25/25 [==============================] - 5s 197ms/step
#
# Total image count, IMG_4460.JPG = 376.8
# ____________________________________________________
#
# 24: Km_1/IMG_4461.JPG
# img.shape (3168, 4752, 3)
#
#    Horizontal position of vertical lines:
#    left_limit: 882 px, rigth_limit: 4373 px
#    net width: 3491 px
#
#    patches.shape (117, 256, 256, 3)
# 30/30 [==============================] - 6s 196ms/step
#
# Total image count, IMG_4461.JPG = 245.5
# ____________________________________________________
#
# 25: Km_1/IMG_4462.JPG
# img.shape (3168, 4752, 3)
#
#    Horizontal position of vertical lines:
#    left_limit: 1413 px, rigth_limit: 4275 px
#    net width: 2862 px
#
#    patches.shape (99, 256, 256, 3)
# 25/25 [==============================] - 5s 196ms/step
#
# Total image count, IMG_4462.JPG = 269.0
# ____________________________________________________
#
# 26: Km_1/IMG_4463.JPG
# img.shape (3168, 4752, 3)
#
#    Horizontal position of vertical lines:
#    left_limit: 1493 px, rigth_limit: 4343 px
#    net width: 2850 px
#
#    patches.shape (99, 256, 256, 3)
# 25/25 [==============================] - 5s 195ms/step
#
# Total image count, IMG_4463.JPG = 299.1
# ____________________________________________________
#
# 27: Km_1/IMG_4464.JPG
# img.shape (3168, 4752, 3)
#
#    Horizontal position of vertical lines:
#    left_limit: 2282 px, rigth_limit: 4393 px
#    net width: 2111 px
#
#    patches.shape (72, 256, 256, 3)
# 18/18 [==============================] - 4s 194ms/step
#
# Total image count, IMG_4464.JPG = 171.4
# ____________________________________________________
#
# 28: Km_1/IMG_4465.JPG
# img.shape (3168, 4752, 3)
#
#    Horizontal position of vertical lines:
#    left_limit: 1429 px, rigth_limit: 3932 px
#    net width: 2503 px
#
#    patches.shape (81, 256, 256, 3)
# 21/21 [==============================] - 4s 193ms/step
#
# Total image count, IMG_4465.JPG = 256.1
# ____________________________________________________
#
# 29: Km_1/IMG_4466.JPG
# img.shape (3168, 4752, 3)
#
#    Horizontal position of vertical lines:
#    left_limit: 1943 px, rigth_limit: 3615 px
#    net width: 1672 px
#
#    patches.shape (54, 256, 256, 3)
# 14/14 [==============================] - 3s 196ms/step
#
# Total image count, IMG_4466.JPG = 17.1
# ____________________________________________________
#
#
# Total count, sector Km_1 = 6453.4
#
#
# Sector: Km_2, 10 images
#
# 1: Km_2/IMG_4418.JPG
# img.shape (3168, 4752, 3)
#
#    Horizontal position of vertical lines:
#    left_limit: 893 px, rigth_limit: 3997 px
#    net width: 3104 px
#
#    patches.shape (108, 256, 256, 3)
# 27/27 [==============================] - 6s 195ms/step
#
# Total image count, IMG_4418.JPG = 706.3
# ____________________________________________________
#
# 2: Km_2/IMG_4420.JPG
# img.shape (3168, 4752, 3)
#
#    Horizontal position of vertical lines:
#    left_limit: 388 px, rigth_limit: 3916 px
#    net width: 3528 px
#
#    patches.shape (117, 256, 256, 3)
# 30/30 [==============================] - 6s 194ms/step
#
# Total image count, IMG_4420.JPG = 822.9
# ____________________________________________________
#
# 3: Km_2/IMG_4421.JPG
# img.shape (3168, 4752, 3)
#
#    Horizontal position of vertical lines:
#    left_limit: 244 px, rigth_limit: 3452 px
#    net width: 3208 px
#
#    patches.shape (108, 256, 256, 3)
# 27/27 [==============================] - 6s 194ms/step
#
# Total image count, IMG_4421.JPG = 489.3
# ____________________________________________________
#
# 4: Km_2/IMG_4423.JPG
# img.shape (3168, 4752, 3)
#
#    Horizontal position of vertical lines:
#    left_limit: 244 px, rigth_limit: 3459 px
#    net width: 3215 px
#
#    patches.shape (108, 256, 256, 3)
# 27/27 [==============================] - 6s 194ms/step
#
# Total image count, IMG_4423.JPG = 603.5
# ____________________________________________________
#
# 5: Km_2/IMG_4424.JPG
# img.shape (3168, 4752, 3)
#
#    Horizontal position of vertical lines:
#    left_limit: 158 px, rigth_limit: 4045 px
#    net width: 3887 px
#
#    patches.shape (135, 256, 256, 3)
# 34/34 [==============================] - 7s 195ms/step
#
# Total image count, IMG_4424.JPG = 823.5
# ____________________________________________________
#
# 6: Km_2/IMG_4426.JPG
# img.shape (3168, 4752, 3)
#
#    Horizontal position of vertical lines:
#    left_limit: 258 px, rigth_limit: 3946 px
#    net width: 3688 px
#
#    patches.shape (126, 256, 256, 3)
# 32/32 [==============================] - 6s 194ms/step
#
# Total image count, IMG_4426.JPG = 398.6
# ____________________________________________________
#
# 7: Km_2/IMG_4427.JPG
# img.shape (3168, 4752, 3)
#
#    Horizontal position of vertical lines:
#    left_limit: 467 px, rigth_limit: 3647 px
#    net width: 3180 px
#
#    patches.shape (108, 256, 256, 3)
# 27/27 [==============================] - 6s 194ms/step
#
# Total image count, IMG_4427.JPG = 343.2
# ____________________________________________________
#
# 8: Km_2/IMG_4428.JPG
# img.shape (3168, 4752, 3)
#
#    Horizontal position of vertical lines:
#    left_limit: 322 px, rigth_limit: 4088 px
#    net width: 3766 px
#
#    patches.shape (126, 256, 256, 3)
# 32/32 [==============================] - 7s 191ms/step
#
# Total image count, IMG_4428.JPG = 323.9
# ____________________________________________________
#
# 9: Km_2/IMG_4430.JPG
# img.shape (3168, 4752, 3)
#
#    Horizontal position of vertical lines:
#    left_limit: 431 px, rigth_limit: 3870 px
#    net width: 3439 px
#
#    patches.shape (117, 256, 256, 3)
# 30/30 [==============================] - 6s 192ms/step
#
# Total image count, IMG_4430.JPG = 222.7
# ____________________________________________________
#
# 10: Km_2/IMG_4431.JPG
# img.shape (3168, 4752, 3)
#
#    Horizontal position of vertical lines:
#    left_limit: 644 px, rigth_limit: 4083 px
#    net width: 3439 px
#
#    patches.shape (117, 256, 256, 3)
# 30/30 [==============================] - 6s 189ms/step
#
# Total image count, IMG_4431.JPG = 15.9
# ____________________________________________________
#
#
# Total count, sector Km_2 = 4749.8
#
#
# Sector: Km_3, 10 images
#
# 1: Km_3/IMG_4405.JPG
# img.shape (3168, 4752, 3)
#
#    Horizontal position of vertical lines:
#    left_limit: 400 px, rigth_limit: 3931 px
#    net width: 3531 px
#
#    patches.shape (117, 256, 256, 3)
# 30/30 [==============================] - 6s 195ms/step
#
# Total image count, IMG_4405.JPG = 750.0
# ____________________________________________________
#
# 2: Km_3/IMG_4406.JPG
# img.shape (3168, 4752, 3)
#
#    Horizontal position of vertical lines:
#    left_limit: 428 px, rigth_limit: 4054 px
#    net width: 3626 px
#
#    patches.shape (126, 256, 256, 3)
# 32/32 [==============================] - 7s 197ms/step
#
# Total image count, IMG_4406.JPG = 698.6
# ____________________________________________________
#
# 3: Km_3/IMG_4408.JPG
# img.shape (3168, 4752, 3)
#
#    Horizontal position of vertical lines:
#    left_limit: 528 px, rigth_limit: 3874 px
#    net width: 3346 px
#
#    patches.shape (117, 256, 256, 3)
# 30/30 [==============================] - 7s 194ms/step
#
# Total image count, IMG_4408.JPG = 621.2
# ____________________________________________________
#
# 4: Km_3/IMG_4409.JPG
# img.shape (3168, 4752, 3)
#
#    Horizontal position of vertical lines:
#    left_limit: 276 px, rigth_limit: 3825 px
#    net width: 3549 px
#
#    patches.shape (117, 256, 256, 3)
# 30/30 [==============================] - 6s 195ms/step
#
# Total image count, IMG_4409.JPG = 519.3
# ____________________________________________________
#
# 5: Km_3/IMG_4410.JPG
# img.shape (3168, 4752, 3)
#
#    Horizontal position of vertical lines:
#    left_limit: 522 px, rigth_limit: 4055 px
#    net width: 3533 px
#
#    patches.shape (117, 256, 256, 3)
# 30/30 [==============================] - 6s 192ms/step
#
# Total image count, IMG_4410.JPG = 464.6
# ____________________________________________________
#
# 6: Km_3/IMG_4412.JPG
# img.shape (3168, 4752, 3)
#
#    Horizontal position of vertical lines:
#    left_limit: 439 px, rigth_limit: 3976 px
#    net width: 3537 px
#
#    patches.shape (117, 256, 256, 3)
# 30/30 [==============================] - 6s 192ms/step
#
# Total image count, IMG_4412.JPG = 507.5
# ____________________________________________________
#
# 7: Km_3/IMG_4413.JPG
# img.shape (3168, 4752, 3)
#
#    Horizontal position of vertical lines:
#    left_limit: 335 px, rigth_limit: 4241 px
#    net width: 3906 px
#
#    patches.shape (135, 256, 256, 3)
# 34/34 [==============================] - 7s 193ms/step
#
# Total image count, IMG_4413.JPG = 694.8
# ____________________________________________________
#
# 8: Km_3/IMG_4415.JPG
# img.shape (3168, 4752, 3)
#
#    Horizontal position of vertical lines:
#    left_limit: 824 px, rigth_limit: 3840 px
#    net width: 3016 px
#
#    patches.shape (99, 256, 256, 3)
# 25/25 [==============================] - 5s 194ms/step
#
# Total image count, IMG_4415.JPG = 659.7
# ____________________________________________________
#
# 9: Km_3/IMG_4416.JPG
# img.shape (3168, 4752, 3)
#
#    Horizontal position of vertical lines:
#    left_limit: 516 px, rigth_limit: 3886 px
#    net width: 3370 px
#
#    patches.shape (117, 256, 256, 3)
# 30/30 [==============================] - 6s 195ms/step
#
# Total image count, IMG_4416.JPG = 431.7
# ____________________________________________________
#
# 10: Km_3/IMG_4417.JPG
# img.shape (3168, 4752, 3)
#
#    Horizontal position of vertical lines:
#    left_limit: 439 px, rigth_limit: 4272 px
#    net width: 3833 px
#
#    patches.shape (126, 256, 256, 3)
# 32/32 [==============================] - 7s 195ms/step
#
# Total image count, IMG_4417.JPG = 811.8
# ____________________________________________________
#
#
# Total count, sector Km_3 = 6159.2
#
#
# Sector: Km_4, 6 images
#
# 1: Km_4/IMG_4398.JPG
# img.shape (3168, 4752, 3)
#
#    Horizontal position of vertical lines:
#    left_limit: 443 px, rigth_limit: 3720 px
#    net width: 3277 px
#
#    patches.shape (108, 256, 256, 3)
# 27/27 [==============================] - 6s 195ms/step
#
# Total image count, IMG_4398.JPG = 896.7
# ____________________________________________________
#
# 2: Km_4/IMG_4399.JPG
# img.shape (3168, 4752, 3)
#
#    Horizontal position of vertical lines:
#    left_limit: 561 px, rigth_limit: 3734 px
#    net width: 3173 px
#
#    patches.shape (108, 256, 256, 3)
# 27/27 [==============================] - 6s 196ms/step
#
# Total image count, IMG_4399.JPG = 853.7
# ____________________________________________________
#
# 3: Km_4/IMG_4400.JPG
# img.shape (3168, 4752, 3)
#
#    Horizontal position of vertical lines:
#    left_limit: 275 px, rigth_limit: 4150 px
#    net width: 3875 px
#
#    patches.shape (135, 256, 256, 3)
# 34/34 [==============================] - 7s 194ms/step
#
# Total image count, IMG_4400.JPG = 959.9
# ____________________________________________________
#
# 4: Km_4/IMG_4401.JPG
# img.shape (3168, 4752, 3)
#
#    Horizontal position of vertical lines:
#    left_limit: 666 px, rigth_limit: 4266 px
#    net width: 3600 px
#
#    patches.shape (126, 256, 256, 3)
# 32/32 [==============================] - 6s 192ms/step
#
# Total image count, IMG_4401.JPG = 638.6
# ____________________________________________________
#
# 5: Km_4/IMG_4402.JPG
# img.shape (3168, 4752, 3)
#
#    Horizontal position of vertical lines:
#    left_limit: 700 px, rigth_limit: 4002 px
#    net width: 3302 px
#
#    patches.shape (108, 256, 256, 3)
# 27/27 [==============================] - 6s 193ms/step
#
# Total image count, IMG_4402.JPG = 359.0
# ____________________________________________________
#
# 6: Km_4/IMG_4404.JPG
# img.shape (3168, 4752, 3)
#
#    Horizontal position of vertical lines:
#    left_limit: 373 px, rigth_limit: 3950 px
#    net width: 3577 px
#
#    patches.shape (117, 256, 256, 3)
# 30/30 [==============================] - 6s 193ms/step
#
# Total image count, IMG_4404.JPG = 430.6
# ____________________________________________________
#
#
# Total count, sector Km_4 = 4138.5
#
#
# Sector: Km_5, 10 images
#
# 1: Km_5/IMG_4380.jpg
# img.shape (3168, 4752, 3)
#
#    Horizontal position of vertical lines:
#    left_limit: 1923 px, rigth_limit: 3885 px
#    net width: 1962 px
#
#    patches.shape (63, 256, 256, 3)
# 16/16 [==============================] - 3s 193ms/step
#
# Total image count, IMG_4380.jpg = 157.6
# ____________________________________________________
#
# 2: Km_5/IMG_4381.jpg
# img.shape (3168, 4752, 3)
#
#    Horizontal position of vertical lines:
#    left_limit: 2307 px, rigth_limit: 3546 px
#    net width: 1239 px
#
#    patches.shape (36, 256, 256, 3)
# 9/9 [==============================] - 2s 197ms/step
#
# Total image count, IMG_4381.jpg = 102.1
# ____________________________________________________
#
# 3: Km_5/IMG_4387.JPG
# img.shape (3168, 4752, 3)
#
#    Horizontal position of vertical lines:
#    left_limit: 468 px, rigth_limit: 4277 px
#    net width: 3809 px
#
#    patches.shape (126, 256, 256, 3)
# 32/32 [==============================] - 7s 194ms/step
#
# Total image count, IMG_4387.JPG = 576.9
# ____________________________________________________
#
# 4: Km_5/IMG_4389.JPG
# img.shape (3168, 4752, 3)
#
#    Horizontal position of vertical lines:
#    left_limit: 1264 px, rigth_limit: 3741 px
#    net width: 2477 px
#
#    patches.shape (81, 256, 256, 3)
# 21/21 [==============================] - 4s 195ms/step
#
# Total image count, IMG_4389.JPG = 549.8
# ____________________________________________________
#
# 5: Km_5/IMG_4390.JPG
# img.shape (3168, 4752, 3)
#
#    Horizontal position of vertical lines:
#    left_limit: 395 px, rigth_limit: 3733 px
#    net width: 3338 px
#
#    patches.shape (117, 256, 256, 3)
# 30/30 [==============================] - 6s 195ms/step
#
# Total image count, IMG_4390.JPG = 512.7
# ____________________________________________________
#
# 6: Km_5/IMG_4391.JPG
# img.shape (3168, 4752, 3)
#
#    Horizontal position of vertical lines:
#    left_limit: 521 px, rigth_limit: 3829 px
#    net width: 3308 px
#
#    patches.shape (108, 256, 256, 3)
# 27/27 [==============================] - 5s 193ms/step
#
# Total image count, IMG_4391.JPG = 565.0
# ____________________________________________________
#
# 7: Km_5/IMG_4393.JPG
# img.shape (3168, 4752, 3)
#
#    Horizontal position of vertical lines:
#    left_limit: 426 px, rigth_limit: 4044 px
#    net width: 3618 px
#
#    patches.shape (126, 256, 256, 3)
# 32/32 [==============================] - 7s 193ms/step
#
# Total image count, IMG_4393.JPG = 530.9
# ____________________________________________________
#
# 8: Km_5/IMG_4394.JPG
# img.shape (3168, 4752, 3)
#
#    Horizontal position of vertical lines:
#    left_limit: 486 px, rigth_limit: 3773 px
#    net width: 3287 px
#
#    patches.shape (108, 256, 256, 3)
# 27/27 [==============================] - 6s 194ms/step
#
# Total image count, IMG_4394.JPG = 510.8
# ____________________________________________________
#
# 9: Km_5/IMG_4395.JPG
# img.shape (3168, 4752, 3)
#
#    Horizontal position of vertical lines:
#    left_limit: 454 px, rigth_limit: 3585 px
#    net width: 3131 px
#
#    patches.shape (108, 256, 256, 3)
# 27/27 [==============================] - 6s 193ms/step
#
# Total image count, IMG_4395.JPG = 624.4
# ____________________________________________________
#
# 10: Km_5/IMG_4396.JPG
# img.shape (3168, 4752, 3)
#
#    Horizontal position of vertical lines:
#    left_limit: 506 px, rigth_limit: 4030 px
#    net width: 3524 px
#
#    patches.shape (117, 256, 256, 3)
# 30/30 [==============================] - 6s 195ms/step
#
# Total image count, IMG_4396.JPG = 920.1
# ____________________________________________________
#
#
# Total count, sector Km_5 = 5050.3
#
#
# Sector: Km_6, 40 images
#
# 1: Km_6/IMG_4337.jpg
# img.shape (3168, 4752, 3)
#
#    Horizontal position of vertical lines:
#    left_limit: 1449 px, rigth_limit: 4431 px
#    net width: 2982 px
#
#    patches.shape (99, 256, 256, 3)
# 25/25 [==============================] - 5s 193ms/step
#
# Total image count, IMG_4337.jpg = 419.6
# ____________________________________________________
#
# 2: Km_6/IMG_4338.jpg
# img.shape (3168, 4752, 3)
#
#    Horizontal position of vertical lines:
#    left_limit: 1788 px, rigth_limit: 3704 px
#    net width: 1916 px
#
#    patches.shape (63, 256, 256, 3)
# 16/16 [==============================] - 3s 196ms/step
#
# Total image count, IMG_4338.jpg = 8.7
# ____________________________________________________
#
# 3: Km_6/IMG_4339.jpg
# img.shape (3168, 4752, 3)
#
#    Horizontal position of vertical lines:
#    left_limit: 1101 px, rigth_limit: 4350 px
#    net width: 3249 px
#
#    patches.shape (108, 256, 256, 3)
# 27/27 [==============================] - 5s 193ms/step
#
# Total image count, IMG_4339.jpg = 185.4
# ____________________________________________________
#
# 4: Km_6/IMG_4340.jpg
# img.shape (3168, 4752, 3)
#
#    Horizontal position of vertical lines:
#    left_limit: 1326 px, rigth_limit: 4177 px
#    net width: 2851 px
#
#    patches.shape (99, 256, 256, 3)
# 25/25 [==============================] - 5s 194ms/step
#
# Total image count, IMG_4340.jpg = 322.0
# ____________________________________________________
#
# 5: Km_6/IMG_4341.jpg
# img.shape (3168, 4752, 3)
#
#    Horizontal position of vertical lines:
#    left_limit: 1216 px, rigth_limit: 3941 px
#    net width: 2725 px
#
#    patches.shape (90, 256, 256, 3)
# 23/23 [==============================] - 5s 193ms/step
#
# Total image count, IMG_4341.jpg = 255.2
# ____________________________________________________
#
# 6: Km_6/IMG_4342.jpg
# img.shape (3168, 4752, 3)
#
#    Horizontal position of vertical lines:
#    left_limit: 1032 px, rigth_limit: 3855 px
#    net width: 2823 px
#
#    patches.shape (99, 256, 256, 3)
# 25/25 [==============================] - 5s 193ms/step
#
# Total image count, IMG_4342.jpg = 425.9
# ____________________________________________________
#
# 7: Km_6/IMG_4343.jpg
# img.shape (3168, 4752, 3)
#
#    Horizontal position of vertical lines:
#    left_limit: 525 px, rigth_limit: 4374 px
#    net width: 3849 px
#
#    patches.shape (135, 256, 256, 3)
# 34/34 [==============================] - 7s 195ms/step
#
# Total image count, IMG_4343.jpg = 577.3
# ____________________________________________________
#
# 8: Km_6/IMG_4344.jpg
# img.shape (3168, 4752, 3)
#
#    Horizontal position of vertical lines:
#    left_limit: 1097 px, rigth_limit: 3970 px
#    net width: 2873 px
#
#    patches.shape (99, 256, 256, 3)
# 25/25 [==============================] - 5s 194ms/step
#
# Total image count, IMG_4344.jpg = 108.5
# ____________________________________________________
#
# 9: Km_6/IMG_4345.jpg
# img.shape (3168, 4752, 3)
#
#    Horizontal position of vertical lines:
#    left_limit: 623 px, rigth_limit: 4421 px
#    net width: 3798 px
#
#    patches.shape (126, 256, 256, 3)
# 32/32 [==============================] - 7s 194ms/step
#
# Total image count, IMG_4345.jpg = 587.0
# ____________________________________________________
#
# 10: Km_6/IMG_4347.jpg
# img.shape (3168, 4752, 3)
#
#    Horizontal position of vertical lines:
#    left_limit: 1172 px, rigth_limit: 4061 px
#    net width: 2889 px
#
#    patches.shape (99, 256, 256, 3)
# 25/25 [==============================] - 5s 195ms/step
#
# Total image count, IMG_4347.jpg = 197.2
# ____________________________________________________
#
# 11: Km_6/IMG_4348.jpg
# img.shape (3168, 4752, 3)
#
#    Horizontal position of vertical lines:
#    left_limit: 642 px, rigth_limit: 4381 px
#    net width: 3739 px
#
#    patches.shape (126, 256, 256, 3)
# 32/32 [==============================] - 6s 193ms/step
#
# Total image count, IMG_4348.jpg = 217.0
# ____________________________________________________
#
# 12: Km_6/IMG_4349.jpg
# img.shape (3168, 4752, 3)
#
#    Horizontal position of vertical lines:
#    left_limit: 1479 px, rigth_limit: 4448 px
#    net width: 2969 px
#
#    patches.shape (99, 256, 256, 3)
# 25/25 [==============================] - 5s 194ms/step
#
# Total image count, IMG_4349.jpg = 155.6
# ____________________________________________________
#
# 13: Km_6/IMG_4350.jpg
# img.shape (3168, 4752, 3)
#
#    Horizontal position of vertical lines:
#    left_limit: 1487 px, rigth_limit: 4066 px
#    net width: 2579 px
#
#    patches.shape (90, 256, 256, 3)
# 23/23 [==============================] - 5s 196ms/step
#
# Total image count, IMG_4350.jpg = 83.6
# ____________________________________________________
#
# 14: Km_6/IMG_4351.jpg
# img.shape (3168, 4752, 3)
#
#    Horizontal position of vertical lines:
#    left_limit: 1156 px, rigth_limit: 3864 px
#    net width: 2708 px
#
#    patches.shape (90, 256, 256, 3)
# 23/23 [==============================] - 5s 196ms/step
#
# Total image count, IMG_4351.jpg = 396.2
# ____________________________________________________
#
# 15: Km_6/IMG_4352.jpg
# img.shape (3168, 4752, 3)
#
#    Horizontal position of vertical lines:
#    left_limit: 1236 px, rigth_limit: 3834 px
#    net width: 2598 px
#
#    patches.shape (90, 256, 256, 3)
# 23/23 [==============================] - 5s 194ms/step
#
# Total image count, IMG_4352.jpg = 259.9
# ____________________________________________________
#
# 16: Km_6/IMG_4353.jpg
# img.shape (3168, 4752, 3)
#
#    Horizontal position of vertical lines:
#    left_limit: 1004 px, rigth_limit: 4148 px
#    net width: 3144 px
#
#    patches.shape (108, 256, 256, 3)
# 27/27 [==============================] - 6s 197ms/step
#
# Total image count, IMG_4353.jpg = 369.9
# ____________________________________________________
#
# 17: Km_6/IMG_4354.jpg
# img.shape (3168, 4752, 3)
#
#    Horizontal position of vertical lines:
#    left_limit: 1204 px, rigth_limit: 4530 px
#    net width: 3326 px
#
#    patches.shape (108, 256, 256, 3)
# 27/27 [==============================] - 6s 195ms/step
#
# Total image count, IMG_4354.jpg = 217.7
# ____________________________________________________
#
# 18: Km_6/IMG_4355.jpg
# img.shape (3168, 4752, 3)
#
#    Horizontal position of vertical lines:
#    left_limit: 1490 px, rigth_limit: 4182 px
#    net width: 2692 px
#
#    patches.shape (90, 256, 256, 3)
# 23/23 [==============================] - 5s 196ms/step
#
# Total image count, IMG_4355.jpg = 48.7
# ____________________________________________________
#
# 19: Km_6/IMG_4356.jpg
# img.shape (3168, 4752, 3)
#
#    Horizontal position of vertical lines:
#    left_limit: 1512 px, rigth_limit: 4546 px
#    net width: 3034 px
#
#    patches.shape (99, 256, 256, 3)
# 25/25 [==============================] - 5s 195ms/step
#
# Total image count, IMG_4356.jpg = 221.6
# ____________________________________________________
#
# 20: Km_6/IMG_4357.jpg
# img.shape (3168, 4752, 3)
#
#    Horizontal position of vertical lines:
#    left_limit: 2118 px, rigth_limit: 4309 px
#    net width: 2191 px
#
#    patches.shape (72, 256, 256, 3)
# 18/18 [==============================] - 4s 197ms/step
#
# Total image count, IMG_4357.jpg = 178.4
# ____________________________________________________
#
# 21: Km_6/IMG_4358.jpg
# img.shape (3168, 4752, 3)
#
#    Horizontal position of vertical lines:
#    left_limit: 1468 px, rigth_limit: 4512 px
#    net width: 3044 px
#
#    patches.shape (99, 256, 256, 3)
# 25/25 [==============================] - 6s 197ms/step
#
# Total image count, IMG_4358.jpg = 257.7
# ____________________________________________________
#
# 22: Km_6/IMG_4359.jpg
# img.shape (3168, 4752, 3)
#
#    Horizontal position of vertical lines:
#    left_limit: 1352 px, rigth_limit: 4426 px
#    net width: 3074 px
#
#    patches.shape (108, 256, 256, 3)
# 27/27 [==============================] - 6s 195ms/step
#
# Total image count, IMG_4359.jpg = 196.1
# ____________________________________________________
#
# 23: Km_6/IMG_4360.jpg
# img.shape (3168, 4752, 3)
#
#    Horizontal position of vertical lines:
#    left_limit: 1489 px, rigth_limit: 3722 px
#    net width: 2233 px
#
#    patches.shape (72, 256, 256, 3)
# 18/18 [==============================] - 4s 197ms/step
#
# Total image count, IMG_4360.jpg = 91.3
# ____________________________________________________
#
# 24: Km_6/IMG_4362.jpg
# img.shape (3168, 4752, 3)
#
#    Horizontal position of vertical lines:
#    left_limit: 1080 px, rigth_limit: 3858 px
#    net width: 2778 px
#
#    patches.shape (90, 256, 256, 3)
# 23/23 [==============================] - 5s 197ms/step
#
# Total image count, IMG_4362.jpg = 187.7
# ____________________________________________________
#
# 25: Km_6/IMG_4363.jpg
# img.shape (3168, 4752, 3)
#
#    Horizontal position of vertical lines:
#    left_limit: 972 px, rigth_limit: 3582 px
#    net width: 2610 px
#
#    patches.shape (90, 256, 256, 3)
# 23/23 [==============================] - 5s 196ms/step
#
# Total image count, IMG_4363.jpg = 57.7
# ____________________________________________________
#
# 26: Km_6/IMG_4364.jpg
# img.shape (3168, 4752, 3)
#
#    Horizontal position of vertical lines:
#    left_limit: 856 px, rigth_limit: 3774 px
#    net width: 2918 px
#
#    patches.shape (99, 256, 256, 3)
# 25/25 [==============================] - 5s 196ms/step
#
# Total image count, IMG_4364.jpg = 1.1
# ____________________________________________________
#
# 27: Km_6/IMG_4365.jpg
# img.shape (3168, 4752, 3)
#
#    Horizontal position of vertical lines:
#    left_limit: 1164 px, rigth_limit: 3594 px
#    net width: 2430 px
#
#    patches.shape (81, 256, 256, 3)
# 21/21 [==============================] - 4s 193ms/step
#
# Total image count, IMG_4365.jpg = 170.2
# ____________________________________________________
#
# 28: Km_6/IMG_4366.jpg
# img.shape (3168, 4752, 3)
#
#    Horizontal position of vertical lines:
#    left_limit: 1508 px, rigth_limit: 4070 px
#    net width: 2562 px
#
#    patches.shape (90, 256, 256, 3)
# 23/23 [==============================] - 6s 195ms/step
#
# Total image count, IMG_4366.jpg = 156.7
# ____________________________________________________
#
# 29: Km_6/IMG_4367.jpg
# img.shape (3168, 4752, 3)
#
#    Horizontal position of vertical lines:
#    left_limit: 2150 px, rigth_limit: 3913 px
#    net width: 1763 px
#
#    patches.shape (54, 256, 256, 3)
# 14/14 [==============================] - 3s 198ms/step
#
# Total image count, IMG_4367.jpg = 7.8
# ____________________________________________________
#
# 30: Km_6/IMG_4368.jpg
# img.shape (3168, 4752, 3)
#
#    Horizontal position of vertical lines:
#    left_limit: 815 px, rigth_limit: 4045 px
#    net width: 3230 px
#
#    patches.shape (108, 256, 256, 3)
# 27/27 [==============================] - 6s 194ms/step
#
# Total image count, IMG_4368.jpg = 306.9
# ____________________________________________________
#
# 31: Km_6/IMG_4369.jpg
# img.shape (3168, 4752, 3)
#
#    Horizontal position of vertical lines:
#    left_limit: 1604 px, rigth_limit: 4338 px
#    net width: 2734 px
#
#    patches.shape (90, 256, 256, 3)
# 23/23 [==============================] - 5s 195ms/step
#
# Total image count, IMG_4369.jpg = 345.4
# ____________________________________________________
#
# 32: Km_6/IMG_4370.jpg
# img.shape (3168, 4752, 3)
#
#    Horizontal position of vertical lines:
#    left_limit: 1892 px, rigth_limit: 3640 px
#    net width: 1748 px
#
#    patches.shape (54, 256, 256, 3)
# 14/14 [==============================] - 3s 197ms/step
#
# Total image count, IMG_4370.jpg = 62.9
# ____________________________________________________
#
# 33: Km_6/IMG_4371.jpg
# img.shape (3168, 4752, 3)
#
#    Horizontal position of vertical lines:
#    left_limit: 1395 px, rigth_limit: 4110 px
#    net width: 2715 px
#
#    patches.shape (90, 256, 256, 3)
# 23/23 [==============================] - 5s 194ms/step
#
# Total image count, IMG_4371.jpg = 164.7
# ____________________________________________________
#
# 34: Km_6/IMG_4373.jpg
# img.shape (3168, 4752, 3)
#
#    Horizontal position of vertical lines:
#    left_limit: 1824 px, rigth_limit: 3574 px
#    net width: 1750 px
#
#    patches.shape (54, 256, 256, 3)
# 14/14 [==============================] - 3s 200ms/step
#
# Total image count, IMG_4373.jpg = 180.4
# ____________________________________________________
#
# 35: Km_6/IMG_4374.jpg
# img.shape (3168, 4752, 3)
#
#    Horizontal position of vertical lines:
#    left_limit: 1755 px, rigth_limit: 4602 px
#    net width: 2847 px
#
#    patches.shape (99, 256, 256, 3)
# 25/25 [==============================] - 5s 196ms/step
#
# Total image count, IMG_4374.jpg = 182.0
# ____________________________________________________
#
# 36: Km_6/IMG_4375.jpg
# img.shape (3168, 4752, 3)
#
#    Horizontal position of vertical lines:
#    left_limit: 2218 px, rigth_limit: 4110 px
#    net width: 1892 px
#
#    patches.shape (63, 256, 256, 3)
# 16/16 [==============================] - 4s 196ms/step
#
# Total image count, IMG_4375.jpg = 92.4
# ____________________________________________________
#
# 37: Km_6/IMG_4376.jpg
# img.shape (3168, 4752, 3)
#
#    Horizontal position of vertical lines:
#    left_limit: 1974 px, rigth_limit: 3664 px
#    net width: 1690 px
#
#    patches.shape (54, 256, 256, 3)
# 14/14 [==============================] - 3s 198ms/step
#
# Total image count, IMG_4376.jpg = 79.4
# ____________________________________________________
#
# 38: Km_6/IMG_4377.jpg
# img.shape (3168, 4752, 3)
#
#    Horizontal position of vertical lines:
#    left_limit: 2078 px, rigth_limit: 4594 px
#    net width: 2516 px
#
#    patches.shape (81, 256, 256, 3)
# 21/21 [==============================] - 4s 194ms/step
#
# Total image count, IMG_4377.jpg = 191.7
# ____________________________________________________
#
# 39: Km_6/IMG_4378.jpg
# img.shape (3168, 4752, 3)
#
#    Horizontal position of vertical lines:
#    left_limit: 2988 px, rigth_limit: 3458 px
#    net width: 470 px
#
#    patches.shape (9, 256, 256, 3)
# 3/3 [==============================] - 1s 230ms/step
#
# Total image count, IMG_4378.jpg = 80.5
# ____________________________________________________
#
# 40: Km_6/IMG_4379.jpg
# img.shape (3168, 4752, 3)
#
#    Horizontal position of vertical lines:
#    left_limit: 1862 px, rigth_limit: 3750 px
#    net width: 1888 px
#
#    patches.shape (63, 256, 256, 3)
# 16/16 [==============================] - 3s 197ms/step
#
# Total image count, IMG_4379.jpg = 174.4
# ____________________________________________________
#
#
# Total count, sector Km_6 = 8222.7
#
#
# Sector: Km_7, 18 images
#
# 1: Km_7/IMG_4317.jpg
# img.shape (3168, 4752, 3)
#
#    Horizontal position of vertical lines:
#    left_limit: 746 px, rigth_limit: 4086 px
#    net width: 3340 px
#
#    patches.shape (117, 256, 256, 3)
# 30/30 [==============================] - 6s 192ms/step
#
# Total image count, IMG_4317.jpg = 362.9
# ____________________________________________________
#
# 2: Km_7/IMG_4318.jpg
# img.shape (3168, 4752, 3)
#
#    Horizontal position of vertical lines:
#    left_limit: 662 px, rigth_limit: 4216 px
#    net width: 3554 px
#
#    patches.shape (117, 256, 256, 3)
# 30/30 [==============================] - 6s 195ms/step
#
# Total image count, IMG_4318.jpg = 296.9
# ____________________________________________________
#
# 3: Km_7/IMG_4319.jpg
# img.shape (3168, 4752, 3)
#
#    Horizontal position of vertical lines:
#    left_limit: 836 px, rigth_limit: 3362 px
#    net width: 2526 px
#
#    patches.shape (81, 256, 256, 3)
# 21/21 [==============================] - 4s 196ms/step
#
# Total image count, IMG_4319.jpg = 199.2
# ____________________________________________________
#
# 4: Km_7/IMG_4320.jpg
# img.shape (3168, 4752, 3)
#
#    Horizontal position of vertical lines:
#    left_limit: 285 px, rigth_limit: 4246 px
#    net width: 3961 px
#
#    patches.shape (135, 256, 256, 3)
# 34/34 [==============================] - 8s 195ms/step
#
# Total image count, IMG_4320.jpg = 241.8
# ____________________________________________________
#
# 5: Km_7/IMG_4321.jpg
# img.shape (3168, 4752, 3)
#
#    Horizontal position of vertical lines:
#    left_limit: 1215 px, rigth_limit: 2876 px
#    net width: 1661 px
#
#    patches.shape (54, 256, 256, 3)
# 14/14 [==============================] - 3s 198ms/step
#
# Total image count, IMG_4321.jpg = 42.0
# ____________________________________________________
#
# 6: Km_7/IMG_4322.jpg
# img.shape (3168, 4752, 3)
#
#    Horizontal position of vertical lines:
#    left_limit: 184 px, rigth_limit: 4362 px
#    net width: 4178 px
#
#    patches.shape (144, 256, 256, 3)
# 36/36 [==============================] - 7s 195ms/step
#
# Total image count, IMG_4322.jpg = 667.9
# ____________________________________________________
#
# 7: Km_7/IMG_4323.jpg
# img.shape (3168, 4752, 3)
#
#    Horizontal position of vertical lines:
#    left_limit: 1268 px, rigth_limit: 3215 px
#    net width: 1947 px
#
#    patches.shape (63, 256, 256, 3)
# 16/16 [==============================] - 3s 199ms/step
#
# Total image count, IMG_4323.jpg = 368.2
# ____________________________________________________
#
# 8: Km_7/IMG_4324.jpg
# img.shape (3168, 4752, 3)
#
#    Horizontal position of vertical lines:
#    left_limit: 424 px, rigth_limit: 4246 px
#    net width: 3822 px
#
#    patches.shape (126, 256, 256, 3)
# 32/32 [==============================] - 7s 195ms/step
#
# Total image count, IMG_4324.jpg = 41.7
# ____________________________________________________
#
# 9: Km_7/IMG_4325.jpg
# img.shape (3168, 4752, 3)
#
#    Horizontal position of vertical lines:
#    left_limit: 938 px, rigth_limit: 4050 px
#    net width: 3112 px
#
#    patches.shape (108, 256, 256, 3)
# 27/27 [==============================] - 6s 196ms/step
#
# Total image count, IMG_4325.jpg = 332.7
# ____________________________________________________
#
# 10: Km_7/IMG_4326.jpg
# img.shape (3168, 4752, 3)
#
#    Horizontal position of vertical lines:
#    left_limit: 1852 px, rigth_limit: 3354 px
#    net width: 1502 px
#
#    patches.shape (45, 256, 256, 3)
# 12/12 [==============================] - 3s 199ms/step
#
# Total image count, IMG_4326.jpg = 140.1
# ____________________________________________________
#
# 11: Km_7/IMG_4327.jpg
# img.shape (3168, 4752, 3)
#
#    Horizontal position of vertical lines:
#    left_limit: 246 px, rigth_limit: 3418 px
#    net width: 3172 px
#
#    patches.shape (108, 256, 256, 3)
# 27/27 [==============================] - 6s 194ms/step
#
# Total image count, IMG_4327.jpg = 323.7
# ____________________________________________________
#
# 12: Km_7/IMG_4329.jpg
# img.shape (3168, 4752, 3)
#
#    Horizontal position of vertical lines:
#    left_limit: 222 px, rigth_limit: 4058 px
#    net width: 3836 px
#
#    patches.shape (126, 256, 256, 3)
# 32/32 [==============================] - 7s 194ms/step
#
# Total image count, IMG_4329.jpg = 180.9
# ____________________________________________________
#
# 13: Km_7/IMG_4330.jpg
# img.shape (3168, 4752, 3)
#
#    Horizontal position of vertical lines:
#    left_limit: 1436 px, rigth_limit: 3962 px
#    net width: 2526 px
#
#    patches.shape (81, 256, 256, 3)
# 21/21 [==============================] - 4s 196ms/step
#
# Total image count, IMG_4330.jpg = 324.4
# ____________________________________________________
#
# 14: Km_7/IMG_4331.jpg
# img.shape (3168, 4752, 3)
#
#    Horizontal position of vertical lines:
#    left_limit: 1470 px, rigth_limit: 3074 px
#    net width: 1604 px
#
#    patches.shape (54, 256, 256, 3)
# 14/14 [==============================] - 3s 195ms/step
#
# Total image count, IMG_4331.jpg = 46.5
# ____________________________________________________
#
# 15: Km_7/IMG_4332.jpg
# img.shape (3168, 4752, 3)
#
#    Horizontal position of vertical lines:
#    left_limit: 442 px, rigth_limit: 3386 px
#    net width: 2944 px
#
#    patches.shape (99, 256, 256, 3)
# 25/25 [==============================] - 5s 191ms/step
#
# Total image count, IMG_4332.jpg = 489.7
# ____________________________________________________
#
# 16: Km_7/IMG_4333.jpg
# img.shape (3168, 4752, 3)
#
#    Horizontal position of vertical lines:
#    left_limit: 941 px, rigth_limit: 4163 px
#    net width: 3222 px
#
#    patches.shape (108, 256, 256, 3)
# 27/27 [==============================] - 5s 192ms/step
#
# Total image count, IMG_4333.jpg = 383.3
# ____________________________________________________
#
# 17: Km_7/IMG_4334.jpg
# img.shape (3168, 4752, 3)
#
#    Horizontal position of vertical lines:
#    left_limit: 845 px, rigth_limit: 3962 px
#    net width: 3117 px
#
#    patches.shape (108, 256, 256, 3)
# 27/27 [==============================] - 5s 192ms/step
#
# Total image count, IMG_4334.jpg = 148.2
# ____________________________________________________
#
# 18: Km_7/IMG_4335.jpg
# img.shape (3168, 4752, 3)
#
#    Horizontal position of vertical lines:
#    left_limit: 810 px, rigth_limit: 4630 px
#    net width: 3820 px
#
#    patches.shape (126, 256, 256, 3)
# 32/32 [==============================] - 6s 193ms/step
#
# Total image count, IMG_4335.jpg = 499.8
# ____________________________________________________
#
#
# Total count, sector Km_7 = 5089.8
#
#
# Sector: Km_8, 14 images
#
# 1: Km_8/IMG_4301.jpg
# img.shape (3168, 4752, 3)
#
#    Horizontal position of vertical lines:
#    left_limit: 898 px, rigth_limit: 3468 px
#    net width: 2570 px
#
#    patches.shape (90, 256, 256, 3)
# 23/23 [==============================] - 5s 194ms/step
#
# Total image count, IMG_4301.jpg = 205.3
# ____________________________________________________
#
# 2: Km_8/IMG_4302.jpg
# img.shape (3168, 4752, 3)
#
#    Horizontal position of vertical lines:
#    left_limit: 415 px, rigth_limit: 4160 px
#    net width: 3745 px
#
#    patches.shape (126, 256, 256, 3)
# 32/32 [==============================] - 7s 193ms/step
#
# Total image count, IMG_4302.jpg = 283.4
# ____________________________________________________
#
# 3: Km_8/IMG_4303.jpg
# img.shape (3168, 4752, 3)
#
#    Horizontal position of vertical lines:
#    left_limit: 542 px, rigth_limit: 3231 px
#    net width: 2689 px
#
#    patches.shape (90, 256, 256, 3)
# 23/23 [==============================] - 5s 197ms/step
#
# Total image count, IMG_4303.jpg = 185.6
# ____________________________________________________
#
# 4: Km_8/IMG_4304.jpg
# img.shape (3168, 4752, 3)
#
#    Horizontal position of vertical lines:
#    left_limit: 426 px, rigth_limit: 4249 px
#    net width: 3823 px
#
#    patches.shape (126, 256, 256, 3)
# 32/32 [==============================] - 7s 195ms/step
#
# Total image count, IMG_4304.jpg = 405.1
# ____________________________________________________
#
# 5: Km_8/IMG_4305.jpg
# img.shape (3168, 4752, 3)
#
#    Horizontal position of vertical lines:
#    left_limit: 819 px, rigth_limit: 3591 px
#    net width: 2772 px
#
#    patches.shape (90, 256, 256, 3)
# 23/23 [==============================] - 5s 194ms/step
#
# Total image count, IMG_4305.jpg = 149.2
# ____________________________________________________
#
# 6: Km_8/IMG_4306.jpg
# img.shape (3168, 4752, 3)
#
#    Horizontal position of vertical lines:
#    left_limit: 258 px, rigth_limit: 4414 px
#    net width: 4156 px
#
#    patches.shape (144, 256, 256, 3)
# 36/36 [==============================] - 7s 194ms/step
#
# Total image count, IMG_4306.jpg = 332.1
# ____________________________________________________
#
# 7: Km_8/IMG_4308.jpg
# img.shape (3168, 4752, 3)
#
#    Horizontal position of vertical lines:
#    left_limit: 1222 px, rigth_limit: 4152 px
#    net width: 2930 px
#
#    patches.shape (99, 256, 256, 3)
# 25/25 [==============================] - 5s 192ms/step
#
# Total image count, IMG_4308.jpg = 234.3
# ____________________________________________________
#
# 8: Km_8/IMG_4309.jpg
# img.shape (3168, 4752, 3)
#
#    Horizontal position of vertical lines:
#    left_limit: 1354 px, rigth_limit: 4676 px
#    net width: 3322 px
#
#    patches.shape (108, 256, 256, 3)
# 27/27 [==============================] - 6s 195ms/step
#
# Total image count, IMG_4309.jpg = 176.0
# ____________________________________________________
#
# 9: Km_8/IMG_4310.jpg
# img.shape (3168, 4752, 3)
#
#    Horizontal position of vertical lines:
#    left_limit: 2344 px, rigth_limit: 4486 px
#    net width: 2142 px
#
#    patches.shape (72, 256, 256, 3)
# 18/18 [==============================] - 4s 197ms/step
#
# Total image count, IMG_4310.jpg = 165.0
# ____________________________________________________
#
# 10: Km_8/IMG_4311.jpg
# img.shape (3168, 4752, 3)
#
#    Horizontal position of vertical lines:
#    left_limit: 1034 px, rigth_limit: 3802 px
#    net width: 2768 px
#
#    patches.shape (90, 256, 256, 3)
# 23/23 [==============================] - 5s 194ms/step
#
# Total image count, IMG_4311.jpg = 389.9
# ____________________________________________________
#
# 11: Km_8/IMG_4312.jpg
# img.shape (3168, 4752, 3)
#
#    Horizontal position of vertical lines:
#    left_limit: 496 px, rigth_limit: 3958 px
#    net width: 3462 px
#
#    patches.shape (117, 256, 256, 3)
# 30/30 [==============================] - 6s 195ms/step
#
# Total image count, IMG_4312.jpg = 508.1
# ____________________________________________________
#
# 12: Km_8/IMG_4313.jpg
# img.shape (3168, 4752, 3)
#
#    Horizontal position of vertical lines:
#    left_limit: 554 px, rigth_limit: 3832 px
#    net width: 3278 px
#
#    patches.shape (108, 256, 256, 3)
# 27/27 [==============================] - 6s 194ms/step
#
# Total image count, IMG_4313.jpg = 415.0
# ____________________________________________________
#
# 13: Km_8/IMG_4314.jpg
# img.shape (3168, 4752, 3)
#
#    Horizontal position of vertical lines:
#    left_limit: 539 px, rigth_limit: 4154 px
#    net width: 3615 px
#
#    patches.shape (126, 256, 256, 3)
# 32/32 [==============================] - 7s 197ms/step
#
# Total image count, IMG_4314.jpg = 503.3
# ____________________________________________________
#
# 14: Km_8/IMG_4315.jpg
# img.shape (3168, 4752, 3)
#
#    Horizontal position of vertical lines:
#    left_limit: 860 px, rigth_limit: 4338 px
# ...
#
# 1: Km_13/IMG_0958.JPG
# img.shape (3000, 4000, 3)
#
#    Horizontal position of vertical lines:
#    left_limit: 0 px, rigth_limit: 4000 px
#    net width: 4000 px
#
#    patches.shape (135, 256, 256, 3)
# 34/34 [==============================] - 7s 196ms/step
#
# Total image count, IMG_0958.JPG = 134.3
# ____________________________________________________
#
# 2: Km_13/IMG_0960.JPG
# img.shape (3000, 4000, 3)
#
#    Horizontal position of vertical lines:
#    left_limit: 0 px, rigth_limit: 4000 px
#    net width: 4000 px
#
#    patches.shape (135, 256, 256, 3)
# 34/34 [==============================] - 7s 194ms/step
#
# Total image count, IMG_0960.JPG = 157.0
# ____________________________________________________
#
# 3: Km_13/IMG_0961.JPG
# img.shape (3000, 4000, 3)
#
#    Horizontal position of vertical lines:
#    left_limit: 0 px, rigth_limit: 4000 px
#    net width: 4000 px
#
#    patches.shape (135, 256, 256, 3)
# 34/34 [==============================] - 7s 194ms/step
#
# Total image count, IMG_0961.JPG = 45.1
# ____________________________________________________
#
# 4: Km_13/IMG_0962.JPG
# img.shape (3000, 4000, 3)
#
#    Horizontal position of vertical lines:
#    left_limit: 337 px, rigth_limit: 3832 px
#    net width: 3495 px
#
#    patches.shape (117, 256, 256, 3)
# 30/30 [==============================] - 6s 193ms/step
#
# Total image count, IMG_0962.JPG = 69.5
# ____________________________________________________
#
# 5: Km_13/IMG_0964.JPG
# img.shape (3000, 4000, 3)
#
#    Horizontal position of vertical lines:
#    left_limit: 0 px, rigth_limit: 4000 px
#    net width: 4000 px
#
#    patches.shape (135, 256, 256, 3)
# 34/34 [==============================] - 7s 195ms/step
#
# Total image count, IMG_0964.JPG = 53.4
# ____________________________________________________
#
#
# Total count, sector Km_13 = 459.2
#
#
# Sector: Km_14, 7 images
#
# 1: Km_14/IMG_0948.JPG
# img.shape (3000, 4000, 3)
#
#    Horizontal position of vertical lines:
#    left_limit: 0 px, rigth_limit: 4000 px
#    net width: 4000 px
#
#    patches.shape (135, 256, 256, 3)
# 34/34 [==============================] - 7s 197ms/step
#
# Total image count, IMG_0948.JPG = 8.0
# ____________________________________________________
#
# 2: Km_14/IMG_0950.JPG
# img.shape (3000, 4000, 3)
#
#    Horizontal position of vertical lines:
#    left_limit: 0 px, rigth_limit: 4000 px
#    net width: 4000 px
#
#    patches.shape (135, 256, 256, 3)
# 34/34 [==============================] - 7s 197ms/step
#
# Total image count, IMG_0950.JPG = 22.8
# ____________________________________________________
#
# 3: Km_14/IMG_0951.JPG
# img.shape (3000, 4000, 3)
#
#    Horizontal position of vertical lines:
#    left_limit: 0 px, rigth_limit: 4000 px
#    net width: 4000 px
#
#    patches.shape (135, 256, 256, 3)
# 34/34 [==============================] - 7s 196ms/step
#
# Total image count, IMG_0951.JPG = 38.8
# ____________________________________________________
#
# 4: Km_14/IMG_0952.JPG
# img.shape (3000, 4000, 3)
#
#    Horizontal position of vertical lines:
#    left_limit: 469 px, rigth_limit: 2347 px
#    net width: 1878 px
#
#    patches.shape (63, 256, 256, 3)
# 16/16 [==============================] - 4s 199ms/step
#
# Total image count, IMG_0952.JPG = 23.8
# ____________________________________________________
#
# 5: Km_14/IMG_0953.JPG
# img.shape (3000, 4000, 3)
#
#    Horizontal position of vertical lines:
#    left_limit: 0 px, rigth_limit: 4000 px
#    net width: 4000 px
#
#    patches.shape (135, 256, 256, 3)
# 34/34 [==============================] - 7s 195ms/step
#
# Total image count, IMG_0953.JPG = 109.2
# ____________________________________________________
#
# 6: Km_14/IMG_0955.JPG
# img.shape (3000, 4000, 3)
#
#    Horizontal position of vertical lines:
#    left_limit: 0 px, rigth_limit: 4000 px
#    net width: 4000 px
#
#    patches.shape (135, 256, 256, 3)
# 34/34 [==============================] - 7s 196ms/step
#
# Total image count, IMG_0955.JPG = 138.7
# ____________________________________________________
#
# 7: Km_14/IMG_0956.JPG
# img.shape (3000, 4000, 3)
#
#    Horizontal position of vertical lines:
#    left_limit: 0 px, rigth_limit: 4000 px
#    net width: 4000 px
#
#    patches.shape (135, 256, 256, 3)
# 34/34 [==============================] - 7s 195ms/step
#
# Total image count, IMG_0956.JPG = 87.6
# ____________________________________________________
#
#
# Total count, sector Km_14 = 429.0
#
#
# Sector: Km_15, 4 images
#
# 1: Km_15/IMG_0943.JPG
# img.shape (3000, 4000, 3)
#
#    Horizontal position of vertical lines:
#    left_limit: 619 px, rigth_limit: 3335 px
#    net width: 2716 px
#
#    patches.shape (90, 256, 256, 3)
# 23/23 [==============================] - 5s 195ms/step
#
# Total image count, IMG_0943.JPG = 44.0
# ____________________________________________________
#
# 2: Km_15/IMG_0945.JPG
# img.shape (3000, 4000, 3)
#
#    Horizontal position of vertical lines:
#    left_limit: 557 px, rigth_limit: 3538 px
#    net width: 2981 px
#
#    patches.shape (99, 256, 256, 3)
# 25/25 [==============================] - 5s 195ms/step
#
# Total image count, IMG_0945.JPG = 37.2
# ____________________________________________________
#
# 3: Km_15/IMG_0946.JPG
# img.shape (3000, 4000, 3)
#
#    Horizontal position of vertical lines:
#    left_limit: 0 px, rigth_limit: 4000 px
#    net width: 4000 px
#
#    patches.shape (135, 256, 256, 3)
# 34/34 [==============================] - 7s 195ms/step
#
# Total image count, IMG_0946.JPG = 2.8
# ____________________________________________________
#
# 4: Km_15/IMG_0947.JPG
# img.shape (3000, 4000, 3)
#
#    Horizontal position of vertical lines:
#    left_limit: 0 px, rigth_limit: 4000 px
#    net width: 4000 px
#
#    patches.shape (135, 256, 256, 3)
# 34/34 [==============================] - 7s 195ms/step
#
# Total image count, IMG_0947.JPG = 8.0
# ____________________________________________________
#
#
# Total count, sector Km_15 = 92.1
#
#
# Sector: Km_16, 16 images
#
# 1: Km_16/IMG_0913.JPG
# img.shape (3000, 4000, 3)
#
#    Horizontal position of vertical lines:
#    left_limit: 969 px, rigth_limit: 2866 px
#    net width: 1897 px
#
#    patches.shape (63, 256, 256, 3)
# 16/16 [==============================] - 3s 198ms/step
#
# Total image count, IMG_0913.JPG = 19.8
# ____________________________________________________
#
# 2: Km_16/IMG_0914.JPG
# img.shape (3000, 4000, 3)
#
#    Horizontal position of vertical lines:
#    left_limit: 338 px, rigth_limit: 3688 px
#    net width: 3350 px
#
#    patches.shape (117, 256, 256, 3)
# 30/30 [==============================] - 6s 196ms/step
#
# Total image count, IMG_0914.JPG = 55.8
# ____________________________________________________
#
# 3: Km_16/IMG_0915.JPG
# img.shape (3000, 4000, 3)
#
#    Horizontal position of vertical lines:
#    left_limit: 614 px, rigth_limit: 3375 px
#    net width: 2761 px
#
#    patches.shape (90, 256, 256, 3)
# 23/23 [==============================] - 5s 196ms/step
#
# Total image count, IMG_0915.JPG = 40.5
# ____________________________________________________
#
# 4: Km_16/IMG_0916.JPG
# img.shape (3000, 4000, 3)
#
#    Horizontal position of vertical lines:
#    left_limit: 349 px, rigth_limit: 3312 px
#    net width: 2963 px
#
#    patches.shape (99, 256, 256, 3)
# 25/25 [==============================] - 5s 198ms/step
#
# Total image count, IMG_0916.JPG = 36.6
# ____________________________________________________
#
# 5: Km_16/IMG_0917.JPG
# img.shape (3000, 4000, 3)
#
#    Horizontal position of vertical lines:
#    left_limit: 157 px, rigth_limit: 3813 px
#    net width: 3656 px
#
#    patches.shape (126, 256, 256, 3)
# 32/32 [==============================] - 7s 197ms/step
#
# Total image count, IMG_0917.JPG = 34.2
# ____________________________________________________
#
# 6: Km_16/IMG_0918.JPG
# img.shape (3000, 4000, 3)
#
#    Horizontal position of vertical lines:
#    left_limit: 533 px, rigth_limit: 3311 px
#    net width: 2778 px
#
#    patches.shape (90, 256, 256, 3)
# 23/23 [==============================] - 5s 197ms/step
#
# Total image count, IMG_0918.JPG = 24.8
# ____________________________________________________
#
# 7: Km_16/IMG_0919.JPG
# img.shape (3000, 4000, 3)
#
#    Horizontal position of vertical lines:
#    left_limit: 361 px, rigth_limit: 3471 px
#    net width: 3110 px
#
#    patches.shape (108, 256, 256, 3)
# 27/27 [==============================] - 6s 195ms/step
#
# Total image count, IMG_0919.JPG = 45.4
# ____________________________________________________
#
# 8: Km_16/IMG_0920.JPG
# img.shape (3000, 4000, 3)
#
#    Horizontal position of vertical lines:
#    left_limit: 518 px, rigth_limit: 3738 px
#    net width: 3220 px
#
#    patches.shape (108, 256, 256, 3)
# 27/27 [==============================] - 6s 195ms/step
#
# Total image count, IMG_0920.JPG = 42.1
# ____________________________________________________
#
# 9: Km_16/IMG_0921.JPG
# img.shape (3000, 4000, 3)
#
#    Horizontal position of vertical lines:
#    left_limit: 483 px, rigth_limit: 3945 px
#    net width: 3462 px
#
#    patches.shape (117, 256, 256, 3)
# 30/30 [==============================] - 6s 196ms/step
#
# Total image count, IMG_0921.JPG = 105.9
# ____________________________________________________
#
# 10: Km_16/IMG_0923.JPG
# img.shape (3000, 4000, 3)
#
#    Horizontal position of vertical lines:
#    left_limit: 518 px, rigth_limit: 3631 px
#    net width: 3113 px
#
#    patches.shape (108, 256, 256, 3)
# 27/27 [==============================] - 6s 194ms/step
#
# Total image count, IMG_0923.JPG = 70.9
# ____________________________________________________
#
# 11: Km_16/IMG_0926.JPG
# img.shape (3000, 4000, 3)
#
#    Horizontal position of vertical lines:
#    left_limit: 935 px, rigth_limit: 3140 px
#    net width: 2205 px
#
#    patches.shape (72, 256, 256, 3)
# 18/18 [==============================] - 4s 196ms/step
#
# Total image count, IMG_0926.JPG = 69.3
# ____________________________________________________
#
# 12: Km_16/IMG_0927.JPG
# img.shape (3000, 4000, 3)
#
#    Horizontal position of vertical lines:
#    left_limit: 482 px, rigth_limit: 3612 px
#    net width: 3130 px
#
#    patches.shape (108, 256, 256, 3)
# 27/27 [==============================] - 6s 193ms/step
#
# Total image count, IMG_0927.JPG = 88.4
# ____________________________________________________
#
# 13: Km_16/IMG_0928.JPG
# img.shape (3000, 4000, 3)
#
#    Horizontal position of vertical lines:
#    left_limit: 458 px, rigth_limit: 2702 px
#    net width: 2244 px
#
#    patches.shape (72, 256, 256, 3)
# 18/18 [==============================] - 4s 196ms/step
#
# Total image count, IMG_0928.JPG = 73.9
# ____________________________________________________
#
# 14: Km_16/IMG_0929.JPG
# img.shape (3000, 4000, 3)
#
#    Horizontal position of vertical lines:
#    left_limit: 145 px, rigth_limit: 2689 px
#    net width: 2544 px
#
#    patches.shape (81, 256, 256, 3)
# 21/21 [==============================] - 4s 196ms/step
#
# Total image count, IMG_0929.JPG = 81.6
# ____________________________________________________
#
# 15: Km_16/IMG_0930.JPG
# img.shape (3000, 4000, 3)
#
#    Horizontal position of vertical lines:
#    left_limit: 223 px, rigth_limit: 3704 px
#    net width: 3481 px
#
#    patches.shape (117, 256, 256, 3)
# 30/30 [==============================] - 7s 198ms/step
#
# Total image count, IMG_0930.JPG = 159.8
# ____________________________________________________
#
# 16: Km_16/IMG_0931.JPG
# img.shape (3000, 4000, 3)
#
#    Horizontal position of vertical lines:
#    left_limit: 816 px, rigth_limit: 3544 px
#    net width: 2728 px
#
#    patches.shape (90, 256, 256, 3)
# 23/23 [==============================] - 5s 196ms/step
#
# Total image count, IMG_0931.JPG = 126.3
# ____________________________________________________
#
#
# Total count, sector Km_16 = 1075.5
#
#
# Sector: Km_17, 12 images
#
# 1: Km_17/IMG_0899.JPG
# img.shape (3000, 4000, 3)
#
#    Horizontal position of vertical lines:
#    left_limit: 896 px, rigth_limit: 3788 px
#    net width: 2892 px
#
#    patches.shape (99, 256, 256, 3)
# 25/25 [==============================] - 5s 195ms/step
#
# Total image count, IMG_0899.JPG = 112.1
# ____________________________________________________
#
# 2: Km_17/IMG_0900.JPG
# img.shape (3000, 4000, 3)
#
#    Horizontal position of vertical lines:
#    left_limit: 480 px, rigth_limit: 3846 px
#    net width: 3366 px
#
#    patches.shape (117, 256, 256, 3)
# 30/30 [==============================] - 6s 195ms/step
#
# Total image count, IMG_0900.JPG = 142.8
# ____________________________________________________
#
# 3: Km_17/IMG_0901.JPG
# img.shape (3000, 4000, 3)
#
#    Horizontal position of vertical lines:
#    left_limit: 1008 px, rigth_limit: 3655 px
#    net width: 2647 px
#
#    patches.shape (90, 256, 256, 3)
# 23/23 [==============================] - 5s 194ms/step
#
# Total image count, IMG_0901.JPG = 96.7
# ____________________________________________________
#
# 4: Km_17/IMG_0904.JPG
# img.shape (3000, 4000, 3)
#
#    Horizontal position of vertical lines:
#    left_limit: 1123 px, rigth_limit: 3310 px
#    net width: 2187 px
#
#    patches.shape (72, 256, 256, 3)
# 18/18 [==============================] - 4s 196ms/step
#
# Total image count, IMG_0904.JPG = 210.7
# ____________________________________________________
#
# 5: Km_17/IMG_0905.JPG
# img.shape (3000, 4000, 3)
#
#    Horizontal position of vertical lines:
#    left_limit: 327 px, rigth_limit: 3861 px
#    net width: 3534 px
#
#    patches.shape (117, 256, 256, 3)
# 30/30 [==============================] - 6s 197ms/step
#
# Total image count, IMG_0905.JPG = 238.2
# ____________________________________________________
#
# 6: Km_17/IMG_0906.JPG
# img.shape (3000, 4000, 3)
#
#    Horizontal position of vertical lines:
#    left_limit: 1168 px, rigth_limit: 3769 px
#    net width: 2601 px
#
#    patches.shape (90, 256, 256, 3)
# 23/23 [==============================] - 5s 198ms/step
#
# Total image count, IMG_0906.JPG = 90.6
# ____________________________________________________
#
# 7: Km_17/IMG_0907.JPG
# img.shape (3000, 4000, 3)
#
#    Horizontal position of vertical lines:
#    left_limit: 1202 px, rigth_limit: 3567 px
#    net width: 2365 px
#
#    patches.shape (81, 256, 256, 3)
# 21/21 [==============================] - 4s 198ms/step
#
# Total image count, IMG_0907.JPG = 46.8
# ____________________________________________________
#
# 8: Km_17/IMG_0908.JPG
# img.shape (3000, 4000, 3)
#
#    Horizontal position of vertical lines:
#    left_limit: 1268 px, rigth_limit: 3716 px
#    net width: 2448 px
#
#    patches.shape (81, 256, 256, 3)
# 21/21 [==============================] - 4s 196ms/step
#
# Total image count, IMG_0908.JPG = 19.4
# ____________________________________________________
#
# 9: Km_17/IMG_0909.JPG
# img.shape (3000, 4000, 3)
#
#    Horizontal position of vertical lines:
#    left_limit: 898 px, rigth_limit: 3687 px
#    net width: 2789 px
#
#    patches.shape (90, 256, 256, 3)
# 23/23 [==============================] - 5s 195ms/step
#
# Total image count, IMG_0909.JPG = 138.8
# ____________________________________________________
#
# 10: Km_17/IMG_0910.JPG
# img.shape (3000, 4000, 3)
#
#    Horizontal position of vertical lines:
#    left_limit: 1081 px, rigth_limit: 3942 px
#    net width: 2861 px
#
#    patches.shape (99, 256, 256, 3)
# 25/25 [==============================] - 5s 196ms/step
#
# Total image count, IMG_0910.JPG = 104.4
# ____________________________________________________
#
# 11: Km_17/IMG_0911.JPG
# img.shape (3000, 4000, 3)
#
#    Horizontal position of vertical lines:
#    left_limit: 1301 px, rigth_limit: 3776 px
#    net width: 2475 px
#
#    patches.shape (81, 256, 256, 3)
# 21/21 [==============================] - 4s 195ms/step
#
# Total image count, IMG_0911.JPG = 38.9
# ____________________________________________________
#
# 12: Km_17/IMG_0912.JPG
# img.shape (3000, 4000, 3)
#
#    Horizontal position of vertical lines:
#    left_limit: 1286 px, rigth_limit: 3555 px
#    net width: 2269 px
#
#    patches.shape (72, 256, 256, 3)
# 18/18 [==============================] - 4s 197ms/step
#
# Total image count, IMG_0912.JPG = 33.5
# ____________________________________________________
#
#
# Total count, sector Km_17 = 1272.9
#
#
# Sector: Km_18, 1 images
#
# 1: Km_18/IMG_0898.JPG
# img.shape (3000, 4000, 3)
#
#    Horizontal position of vertical lines:
#    left_limit: 426 px, rigth_limit: 3519 px
#    net width: 3093 px
#
#    patches.shape (108, 256, 256, 3)
# 27/27 [==============================] - 6s 193ms/step
#
# Total image count, IMG_0898.JPG = 90.8
# ____________________________________________________
#
#
# Total count, sector Km_18 = 90.8
#
#
#
# ############### TOTAL COLONY COUNT = 53325.5 NEST ENTRANCES ###############
